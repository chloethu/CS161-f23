# %%
import os 
import pandas as pd
import stanza

# %%
#loading files and parser 
#path= #directory where your file is + file name 
path= f'{(os.getcwd())}/NER_Gibon_II/gibbon_decline_volume1_chap21.txt'
#navigate to directory with file you want, replace myfile with the name of your txt file
with open( path, encoding='utf-8', mode='r') as f:
       ch21  = f.read()    #replace my chapter with name for variable

# %%
#parsers 
#loading out NER parser 

nlp_ner= stanza.Pipeline(lang='en', processors='tokenize, ner',tokenize_pretokenized=True)
# Out:
# 2023-10-29 15:26:59 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# 2023-10-29 15:27:00 INFO: Loading these models for language: en (English):
# ================================
# | Processor | Package          |
# --------------------------------
# | tokenize  | combined         |
# | ner       | ontonotes_charlm |
# ================================
#
# 2023-10-29 15:27:00 INFO: Using device: cpu
# 2023-10-29 15:27:00 INFO: Loading: tokenize
# 2023-10-29 15:27:00 INFO: Loading: ner
# 2023-10-29 15:27:01 INFO: Done loading processors!

# %%
#if you want to pretokenize and split your text by sentence 
tokenized_chapter= ch21.split('. ')
#replace my chapter with your actual variable

# %%
#creating a stanza document 
#can take 3-6 mins depending on ur computer setup 
#if you have pre_tokenized the text 
Docs = [stanza.Document([], text=d) for d in tokenized_chapter]
Out_Docs = nlp_ner(Docs)

# %%
#accessing named entities for pre tokenized out_docs 
for doc in Out_Docs:
    print(doc.ents)
# Out:
# [{
#   "text": "The Schism of the Donatists",
#   "type": "WORK_OF_ART",
#   "start_char": 24,
#   "end_char": 51
# }, {
#   "text": "The Arian Controversy — Athanasius — Distracted state of the Church and the Empire under Constantine",
#   "type": "WORK_OF_ART",
#   "start_char": 54,
#   "end_char": 154
# }, {
#   "text": "Toleration of Paganism",
#   "type": "WORK_OF_ART",
#   "start_char": 170,
#   "end_char": 192
# }]
# [{
#   "text": "Constantine",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 11
# }]
# [{
#   "text": "Milan,",
#   "type": "GPE",
#   "start_char": 13,
#   "end_char": 19
# }, {
#   "text": "Roman",
#   "type": "NORP",
#   "start_char": 93,
#   "end_char": 98
# }]
# [{
#   "text": "Catholic",
#   "type": "NORP",
#   "start_char": 164,
#   "end_char": 172
# }, {
#   "text": "Christianity",
#   "type": "NORP",
#   "start_char": 227,
#   "end_char": 239
# }]
# [{
#   "text": "Constantine",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 11
# }]
# []
# [{
#   "text": "East",
#   "type": "LOC",
#   "start_char": 94,
#   "end_char": 98
# }, {
#   "text": "Constantine",
#   "type": "PERSON",
#   "start_char": 231,
#   "end_char": 242
# }, {
#   "text": "Catholic",
#   "type": "NORP",
#   "start_char": 377,
#   "end_char": 385
# }]
# [{
#   "text": "Paul of Samosata; the Montanists of Phrygia,",
#   "type": "PERSON",
#   "start_char": 95,
#   "end_char": 139
# }, {
#   "text": "Novatians,",
#   "type": "NORP",
#   "start_char": 199,
#   "end_char": 209
# }, {
#   "text": "Marcionites",
#   "type": "NORP",
#   "start_char": 272,
#   "end_char": 283
# }, {
#   "text": "Valentinians,",
#   "type": "NORP",
#   "start_char": 288,
#   "end_char": 301
# }, {
#   "text": "Gnostics",
#   "type": "NORP",
#   "start_char": 342,
#   "end_char": 350
# }, {
#   "text": "Asia",
#   "type": "LOC",
#   "start_char": 354,
#   "end_char": 358
# }, {
#   "text": "Egypt",
#   "type": "GPE",
#   "start_char": 363,
#   "end_char": 368
# }, {
#   "text": "Manichaeans,",
#   "type": "NORP",
#   "start_char": 409,
#   "end_char": 421
# }, {
#   "text": "Persia",
#   "type": "GPE",
#   "start_char": 453,
#   "end_char": 459
# }, {
#   "text": "Oriental",
#   "type": "NORP",
#   "start_char": 489,
#   "end_char": 497
# }, {
#   "text": "Christian",
#   "type": "NORP",
#   "start_char": 502,
#   "end_char": 511
# }]
# [{
#   "text": "Diocletian;",
#   "type": "PERSON",
#   "start_char": 61,
#   "end_char": 72
# }]
# [{
#   "text": "Two",
#   "type": "CARDINAL",
#   "start_char": 0,
#   "end_char": 3
# }, {
#   "text": "Constantine",
#   "type": "PERSON",
#   "start_char": 75,
#   "end_char": 86
# }]
# [{
#   "text": "Manichaeans",
#   "type": "NORP",
#   "start_char": 24,
#   "end_char": 35
# }]
# []
# [{
#   "text": "Novatians,",
#   "type": "NORP",
#   "start_char": 121,
#   "end_char": 131
# }]
# [{
#   "text": "Constantinople;",
#   "type": "GPE",
#   "start_char": 116,
#   "end_char": 131
# }, {
#   "text": "Acesius,",
#   "type": "PERSON",
#   "start_char": 194,
#   "end_char": 202
# }, {
#   "text": "Nice;",
#   "type": "PERSON",
#   "start_char": 221,
#   "end_char": 226
# }, {
#   "text": "African",
#   "type": "NORP",
#   "start_char": 390,
#   "end_char": 397
# }]
# [{
#   "text": "312",
#   "type": "CARDINAL",
#   "start_char": 0,
#   "end_char": 3
# }]
# [{
#   "text": "Constantine,",
#   "type": "PERSON",
#   "start_char": 67,
#   "end_char": 79
# }, {
#   "text": "Maxentius",
#   "type": "PERSON",
#   "start_char": 104,
#   "end_char": 113
# }, {
#   "text": "Africa",
#   "type": "LOC",
#   "start_char": 128,
#   "end_char": 134
# }]
# [{
#   "text": "the Columns of Hercules,",
#   "type": "ORG",
#   "start_char": 98,
#   "end_char": 122
# }, {
#   "text": "Carthage,",
#   "type": "GPE",
#   "start_char": 245,
#   "end_char": 254
# }, {
#   "text": "second",
#   "type": "ORDINAL",
#   "start_char": 259,
#   "end_char": 265
# }, {
#   "text": "West Caecilian",
#   "type": "GPE",
#   "start_char": 324,
#   "end_char": 338
# }, {
#   "text": "Majourinus",
#   "type": "ORG",
#   "start_char": 343,
#   "end_char": 353
# }, {
#   "text": "two",
#   "type": "CARDINAL",
#   "start_char": 363,
#   "end_char": 366
# }]
# [{
#   "text": "Cacilian",
#   "type": "PERSON",
#   "start_char": 20,
#   "end_char": 28
# }, {
#   "text": "Numidia",
#   "type": "GPE",
#   "start_char": 217,
#   "end_char": 224
# }]
# [{
#   "text": "Caecilian,",
#   "type": "PERSON",
#   "start_char": 73,
#   "end_char": 83
# }, {
#   "text": "Majorinus,",
#   "type": "PERSON",
#   "start_char": 100,
#   "end_char": 110
# }, {
#   "text": "Numidian",
#   "type": "NORP",
#   "start_char": 287,
#   "end_char": 295
# }]
# [{
#   "text": "the Holy Scriptures",
#   "type": "PERSON",
#   "start_char": 185,
#   "end_char": 204
# }, {
#   "text": "Diocletian",
#   "type": "PERSON",
#   "start_char": 224,
#   "end_char": 234
# }]
# [{
#   "text": "African",
#   "type": "NORP",
#   "start_char": 197,
#   "end_char": 204
# }, {
#   "text": "Christians",
#   "type": "NORP",
#   "start_char": 205,
#   "end_char": 215
# }]
# [{
#   "text": "five",
#   "type": "CARDINAL",
#   "start_char": 110,
#   "end_char": 114
# }, {
#   "text": "first",
#   "type": "ORDINAL",
#   "start_char": 209,
#   "end_char": 214
# }, {
#   "text": "three years",
#   "type": "DATE",
#   "start_char": 258,
#   "end_char": 269
# }]
# [{
#   "text": "Africa,",
#   "type": "GPE",
#   "start_char": 83,
#   "end_char": 90
# }, {
#   "text": "two",
#   "type": "CARDINAL",
#   "start_char": 105,
#   "end_char": 108
# }, {
#   "text": "Rome",
#   "type": "GPE",
#   "start_char": 190,
#   "end_char": 194
# }, {
#   "text": "Arles,",
#   "type": "PERSON",
#   "start_char": 202,
#   "end_char": 208
# }, {
#   "text": "Constantine",
#   "type": "PERSON",
#   "start_char": 237,
#   "end_char": 248
# }, {
#   "text": "Caecilian;",
#   "type": "PERSON",
#   "start_char": 320,
#   "end_char": 330
# }, {
#   "text": "Africa",
#   "type": "LOC",
#   "start_char": 440,
#   "end_char": 446
# }]
# [{
#   "text": "Constantine",
#   "type": "PERSON",
#   "start_char": 119,
#   "end_char": 130
# }, {
#   "text": "Donatist",
#   "type": "ORG",
#   "start_char": 217,
#   "end_char": 225
# }]
# [{
#   "text": "Osius",
#   "type": "PERSON",
#   "start_char": 225,
#   "end_char": 230
# }]
# []
# [{
#   "text": "Schism of the Donatists, A.D",
#   "type": "PERSON",
#   "start_char": 202,
#   "end_char": 230
# }]
# [{
#   "text": "315",
#   "type": "CARDINAL",
#   "start_char": 0,
#   "end_char": 3
# }]
# [{
#   "text": "Africa",
#   "type": "LOC",
#   "start_char": 154,
#   "end_char": 160
# }, {
#   "text": "three",
#   "type": "CARDINAL",
#   "start_char": 167,
#   "end_char": 172
# }, {
#   "text": "Christianity",
#   "type": "NORP",
#   "start_char": 219,
#   "end_char": 231
# }]
# [{
#   "text": "Donatists",
#   "type": "NORP",
#   "start_char": 59,
#   "end_char": 68
# }]
# [{
#   "text": "Caecilian,",
#   "type": "PERSON",
#   "start_char": 145,
#   "end_char": 155
# }, {
#   "text": "Europe",
#   "type": "LOC",
#   "start_char": 357,
#   "end_char": 363
# }, {
#   "text": "Asia",
#   "type": "LOC",
#   "start_char": 368,
#   "end_char": 372
# }, {
#   "text": "African",
#   "type": "NORP",
#   "start_char": 517,
#   "end_char": 524
# }]
# []
# [{
#   "text": "East,",
#   "type": "NORP",
#   "start_char": 75,
#   "end_char": 80
# }]
# []
# [{
#   "text": "Catholic",
#   "type": "NORP",
#   "start_char": 69,
#   "end_char": 77
# }]
# [{
#   "text": "the Holy Eucharist",
#   "type": "PERSON",
#   "start_char": 130,
#   "end_char": 148
# }, {
#   "text": "two",
#   "type": "CARDINAL",
#   "start_char": 323,
#   "end_char": 326
# }, {
#   "text": "Africa,",
#   "type": "GPE",
#   "start_char": 386,
#   "end_char": 393
# }, {
#   "text": "Donatists",
#   "type": "NORP",
#   "start_char": 554,
#   "end_char": 563
# }, {
#   "text": "Numidia,",
#   "type": "GPE",
#   "start_char": 616,
#   "end_char": 624
# }, {
#   "text": "four",
#   "type": "CARDINAL",
#   "start_char": 653,
#   "end_char": 657
# }, {
#   "text": "hundred",
#   "type": "CARDINAL",
#   "start_char": 658,
#   "end_char": 665
# }]
# []
# [{
#   "text": "fourth",
#   "type": "ORDINAL",
#   "start_char": 2,
#   "end_char": 8
# }, {
#   "text": "Donatist",
#   "type": "NORP",
#   "start_char": 21,
#   "end_char": 29
# }]
# [{
#   "text": "first",
#   "type": "ORDINAL",
#   "start_char": 41,
#   "end_char": 46
# }, {
#   "text": "Rogatians",
#   "type": "NORP",
#   "start_char": 160,
#   "end_char": 169
# }, {
#   "text": "the Caesarean Mauritania.(10)",
#   "type": "LOC",
#   "start_char": 330,
#   "end_char": 359
# }, {
#   "text": "Trinitarian",
#   "type": "NORP",
#   "start_char": 364,
#   "end_char": 375
# }]
# [{
#   "text": "Donatists",
#   "type": "NORP",
#   "start_char": 18,
#   "end_char": 27
# }, {
#   "text": "Trinitarian",
#   "type": "NORP",
#   "start_char": 87,
#   "end_char": 98
# }, {
#   "text": "Christian",
#   "type": "NORP",
#   "start_char": 158,
#   "end_char": 167
# }]
# []
# [{
#   "text": "Constantine",
#   "type": "PERSON",
#   "start_char": 16,
#   "end_char": 27
# }, {
#   "text": "Clovis",
#   "type": "PERSON",
#   "start_char": 39,
#   "end_char": 45
# }, {
#   "text": "Theodoric,",
#   "type": "PERSON",
#   "start_char": 50,
#   "end_char": 60
# }, {
#   "text": "Romans",
#   "type": "NORP",
#   "start_char": 96,
#   "end_char": 102
# }, {
#   "text": "Arianism",
#   "type": "NORP",
#   "start_char": 170,
#   "end_char": 178
# }]
# [{
#   "text": "Plato",
#   "type": "PERSON",
#   "start_char": 182,
#   "end_char": 187
# }, {
#   "text": "Plato",
#   "type": "PERSON",
#   "start_char": 241,
#   "end_char": 246
# }]
# [{
#   "text": "Christ 360",
#   "type": "PERSON",
#   "start_char": 7,
#   "end_char": 17
# }]
# [{
#   "text": "Plato,",
#   "type": "PERSON",
#   "start_char": 14,
#   "end_char": 20
# }]
# [{
#   "text": "first",
#   "type": "ORDINAL",
#   "start_char": 66,
#   "end_char": 71
# }, {
#   "text": "Athenian",
#   "type": "NORP",
#   "start_char": 124,
#   "end_char": 132
# }]
# [{
#   "text": "Plato",
#   "type": "PERSON",
#   "start_char": 136,
#   "end_char": 141
# }, {
#   "text": "first",
#   "type": "ORDINAL",
#   "start_char": 214,
#   "end_char": 219
# }]
# [{
#   "text": "three",
#   "type": "CARDINAL",
#   "start_char": 91,
#   "end_char": 96
# }, {
#   "text": "Platonic",
#   "type": "NORP",
#   "start_char": 153,
#   "end_char": 161
# }, {
#   "text": "three",
#   "type": "CARDINAL",
#   "start_char": 172,
#   "end_char": 177
# }, {
#   "text": "Logos",
#   "type": "ORG",
#   "start_char": 257,
#   "end_char": 262
# }, {
#   "text": "the Son of an Eternal",
#   "type": "PERSON",
#   "start_char": 330,
#   "end_char": 351
# }]
# [{
#   "text": "Academy;",
#   "type": "NORP",
#   "start_char": 100,
#   "end_char": 108
# }, {
#   "text": "Plato,",
#   "type": "PERSON",
#   "start_char": 162,
#   "end_char": 168
# }, {
#   "text": "thirty years.(12)",
#   "type": "DATE",
#   "start_char": 236,
#   "end_char": 253
# }, {
#   "text": "Alexandria",
#   "type": "GPE",
#   "start_char": 277,
#   "end_char": 287
# }]
# [{
#   "text": "Christ 300",
#   "type": "PERSON",
#   "start_char": 7,
#   "end_char": 17
# }]
# [{
#   "text": "Macedonians",
#   "type": "NORP",
#   "start_char": 16,
#   "end_char": 27
# }, {
#   "text": "Asia",
#   "type": "LOC",
#   "start_char": 42,
#   "end_char": 46
# }, {
#   "text": "Egypt",
#   "type": "GPE",
#   "start_char": 51,
#   "end_char": 56
# }, {
#   "text": "Greece;",
#   "type": "LANGUAGE",
#   "start_char": 86,
#   "end_char": 93
# }, {
#   "text": "Plato",
#   "type": "PERSON",
#   "start_char": 124,
#   "end_char": 129
# }, {
#   "text": "Alexandria.",
#   "type": "GPE",
#   "start_char": 225,
#   "end_char": 236
# }, {
#   "text": "Jews",
#   "type": "NORP",
#   "start_char": 263,
#   "end_char": 267
# }, {
#   "text": "Hebrews",
#   "type": "NORP",
#   "start_char": 472,
#   "end_char": 479
# }]
# [{
#   "text": "Athenian",
#   "type": "NORP",
#   "start_char": 93,
#   "end_char": 101
# }]
# [{
#   "text": "Egyptian",
#   "type": "NORP",
#   "start_char": 230,
#   "end_char": 238
# }]
# [{
#   "text": "One hundred years before",
#   "type": "DATE",
#   "start_char": 0,
#   "end_char": 24
# }, {
#   "text": "Christ,",
#   "type": "PERSON",
#   "start_char": 38,
#   "end_char": 45
# }, {
#   "text": "Alexandrian",
#   "type": "NORP",
#   "start_char": 166,
#   "end_char": 177
# }, {
#   "text": "Solomon",
#   "type": "PERSON",
#   "start_char": 267,
#   "end_char": 274
# }]
# [{
#   "text": "Mosaic",
#   "type": "NORP",
#   "start_char": 28,
#   "end_char": 34
# }, {
#   "text": "Grecian",
#   "type": "NORP",
#   "start_char": 49,
#   "end_char": 56
# }, {
#   "text": "Philo,",
#   "type": "PERSON",
#   "start_char": 95,
#   "end_char": 101
# }, {
#   "text": "Hebrews;",
#   "type": "PERSON",
#   "start_char": 243,
#   "end_char": 251
# }, {
#   "text": "the Logos to the Jehovah of Moses",
#   "type": "WORK_OF_ART",
#   "start_char": 286,
#   "end_char": 319
# }, {
#   "text": "the Son of God",
#   "type": "PERSON",
#   "start_char": 344,
#   "end_char": 358
# }, {
#   "text": "the Apostle St John, A.D",
#   "type": "PERSON",
#   "start_char": 558,
#   "end_char": 582
# }]
# [{
#   "text": "97",
#   "type": "CARDINAL",
#   "start_char": 0,
#   "end_char": 2
# }]
# [{
#   "text": "Plato,",
#   "type": "PERSON",
#   "start_char": 17,
#   "end_char": 23
# }, {
#   "text": "Alexandria,",
#   "type": "GPE",
#   "start_char": 76,
#   "end_char": 87
# }, {
#   "text": "Jews",
#   "type": "NORP",
#   "start_char": 111,
#   "end_char": 115
# }]
# [{
#   "text": "Deity,",
#   "type": "PERSON",
#   "start_char": 39,
#   "end_char": 45
# }, {
#   "text": "Plato",
#   "type": "PERSON",
#   "start_char": 130,
#   "end_char": 135
# }, {
#   "text": "Academy, the Porch,",
#   "type": "PERSON",
#   "start_char": 210,
#   "end_char": 229
# }, {
#   "text": "Logos",
#   "type": "ORG",
#   "start_char": 287,
#   "end_char": 292
# }]
# [{
#   "text": "Christian",
#   "type": "NORP",
#   "start_char": 9,
#   "end_char": 18
# }, {
#   "text": "Nerva,",
#   "type": "PERSON",
#   "start_char": 72,
#   "end_char": 78
# }, {
#   "text": "Jesus of Nazareth;",
#   "type": "PERSON",
#   "start_char": 283,
#   "end_char": 301
# }]
# [{
#   "text": "two",
#   "type": "CARDINAL",
#   "start_char": 227,
#   "end_char": 230
# }, {
#   "text": "Ebionites",
#   "type": "PERSON",
#   "start_char": 309,
#   "end_char": 318
# }, {
#   "text": "Docetes",
#   "type": "ORG",
#   "start_char": 323,
#   "end_char": 330
# }]
# [{
#   "text": "Nazarenes,(23)",
#   "type": "PERSON",
#   "start_char": 48,
#   "end_char": 62
# }]
# [{
#   "text": "Jesus",
#   "type": "PERSON",
#   "start_char": 13,
#   "end_char": 18
# }]
# [{
#   "text": "Hewbrew",
#   "type": "NORP",
#   "start_char": 79,
#   "end_char": 86
# }, {
#   "text": "Son of God,",
#   "type": "PERSON",
#   "start_char": 330,
#   "end_char": 341
# }]
# [{
#   "text": "John",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 4
# }]
# [{
#   "text": "About fifty years",
#   "type": "DATE",
#   "start_char": 0,
#   "end_char": 17
# }, {
#   "text": "Ebionites,",
#   "type": "NORP",
#   "start_char": 34,
#   "end_char": 44
# }, {
#   "text": "Justin Martyr,",
#   "type": "PERSON",
#   "start_char": 75,
#   "end_char": 89
# }, {
#   "text": "Christian",
#   "type": "NORP",
#   "start_char": 185,
#   "end_char": 194
# }]
# []
# [{
#   "text": "Gnostics,",
#   "type": "NORP",
#   "start_char": 4,
#   "end_char": 13
# }]
# [{
#   "text": "Plato,",
#   "type": "GPE",
#   "start_char": 26,
#   "end_char": 32
# }, {
#   "text": "Aeon,",
#   "type": "PERSON",
#   "start_char": 120,
#   "end_char": 125
# }, {
#   "text": "Emanation of the Deity,",
#   "type": "PERSON",
#   "start_char": 129,
#   "end_char": 152
# }]
# [{
#   "text": "Mount Calvary,",
#   "type": "LOC",
#   "start_char": 40,
#   "end_char": 54
# }, {
#   "text": "Virgin,(27)",
#   "type": "PERSON",
#   "start_char": 162,
#   "end_char": 173
# }, {
#   "text": "Jordan",
#   "type": "GPE",
#   "start_char": 211,
#   "end_char": 217
# }, {
#   "text": "Pilate",
#   "type": "PERSON",
#   "start_char": 347,
#   "end_char": 353
# }, {
#   "text": "three days,",
#   "type": "DATE",
#   "start_char": 451,
#   "end_char": 462
# }, {
#   "text": "Mysterious nature of the Trinity",
#   "type": "PERSON",
#   "start_char": 490,
#   "end_char": 522
# }]
# [{
#   "text": "Plato",
#   "type": "PERSON",
#   "start_char": 99,
#   "end_char": 104
# }, {
#   "text": "the second and third centuries",
#   "type": "DATE",
#   "start_char": 142,
#   "end_char": 172
# }, {
#   "text": "Athenian",
#   "type": "NORP",
#   "start_char": 213,
#   "end_char": 221
# }, {
#   "text": "Christian",
#   "type": "NORP",
#   "start_char": 312,
#   "end_char": 321
# }]
# [{
#   "text": "Plato",
#   "type": "PERSON",
#   "start_char": 24,
#   "end_char": 29
# }]
# [{
#   "text": "three",
#   "type": "CARDINAL",
#   "start_char": 119,
#   "end_char": 124
# }, {
#   "text": "Trinity,(31)",
#   "type": "PERSON",
#   "start_char": 168,
#   "end_char": 180
# }, {
#   "text": "Christian",
#   "type": "NORP",
#   "start_char": 227,
#   "end_char": 236
# }, {
#   "text": "Alexandria",
#   "type": "GPE",
#   "start_char": 248,
#   "end_char": 258
# }]
# []
# [{
#   "text": "Christian",
#   "type": "NORP",
#   "start_char": 30,
#   "end_char": 39
# }, {
#   "text": "Athanasius",
#   "type": "PERSON",
#   "start_char": 63,
#   "end_char": 73
# }, {
#   "text": "the divinity of the Logos,",
#   "type": "PERSON",
#   "start_char": 169,
#   "end_char": 195
# }]
# []
# []
# [{
#   "text": "two",
#   "type": "CARDINAL",
#   "start_char": 174,
#   "end_char": 177
# }, {
#   "text": "Platonic",
#   "type": "NORP",
#   "start_char": 297,
#   "end_char": 305
# }, {
#   "text": "Zeal of the Christians.",
#   "type": "PERSON",
#   "start_char": 314,
#   "end_char": 337
# }]
# [{
#   "text": "Athens",
#   "type": "GPE",
#   "start_char": 153,
#   "end_char": 159
# }, {
#   "text": "Alexandria,",
#   "type": "GPE",
#   "start_char": 178,
#   "end_char": 189
# }]
# [{
#   "text": "Roman",
#   "type": "NORP",
#   "start_char": 442,
#   "end_char": 447
# }]
# [{
#   "text": "Tertullian",
#   "type": "PERSON",
#   "start_char": 240,
#   "end_char": 250
# }, {
#   "text": "Christian",
#   "type": "NORP",
#   "start_char": 263,
#   "end_char": 272
# }, {
#   "text": "Grecian",
#   "type": "NORP",
#   "start_char": 353,
#   "end_char": 360
# }]
# []
# []
# []
# [{
#   "text": "Greek",
#   "type": "NORP",
#   "start_char": 68,
#   "end_char": 73
# }]
# [{
#   "text": "Son",
#   "type": "PERSON",
#   "start_char": 17,
#   "end_char": 20
# }, {
#   "text": "the Son of an eternal",
#   "type": "PERSON",
#   "start_char": 320,
#   "end_char": 341
# }]
# [{
#   "text": "Christ,",
#   "type": "PERSON",
#   "start_char": 36,
#   "end_char": 43
# }, {
#   "text": "Christians",
#   "type": "NORP",
#   "start_char": 48,
#   "end_char": 58
# }, {
#   "text": "Bithynia",
#   "type": "GPE",
#   "start_char": 62,
#   "end_char": 70
# }, {
#   "text": "Pliny",
#   "type": "PERSON",
#   "start_char": 103,
#   "end_char": 108
# }, {
#   "text": "Christ,",
#   "type": "PERSON",
#   "start_char": 316,
#   "end_char": 323
# }, {
#   "text": "Father of Christ,",
#   "type": "PERSON",
#   "start_char": 628,
#   "end_char": 645
# }]
# [{
#   "text": "Christians",
#   "type": "NORP",
#   "start_char": 58,
#   "end_char": 68
# }, {
#   "text": "Arian",
#   "type": "NORP",
#   "start_char": 228,
#   "end_char": 233
# }]
# []
# [{
#   "text": "first",
#   "type": "ORDINAL",
#   "start_char": 36,
#   "end_char": 41
# }, {
#   "text": "Christians",
#   "type": "NORP",
#   "start_char": 79,
#   "end_char": 89
# }, {
#   "text": "Platonists:",
#   "type": "NORP",
#   "start_char": 99,
#   "end_char": 110
# }, {
#   "text": "second",
#   "type": "ORDINAL",
#   "start_char": 115,
#   "end_char": 121
# }]
# []
# [{
#   "text": "Christians",
#   "type": "NORP",
#   "start_char": 8,
#   "end_char": 18
# }]
# []
# []
# [{
#   "text": "Platonic",
#   "type": "NORP",
#   "start_char": 107,
#   "end_char": 115
# }]
# [{
#   "text": "Praxeas",
#   "type": "GPE",
#   "start_char": 32,
#   "end_char": 39
# }, {
#   "text": "Sabellius",
#   "type": "PERSON",
#   "start_char": 44,
#   "end_char": 53
# }, {
#   "text": "the Father with the Son,",
#   "type": "PERSON",
#   "start_char": 75,
#   "end_char": 99
# }]
# [{
#   "text": "Sabellians",
#   "type": "PERSON",
#   "start_char": 76,
#   "end_char": 86
# }, {
#   "text": "Rome,",
#   "type": "GPE",
#   "start_char": 140,
#   "end_char": 145
# }, {
#   "text": "Africa,",
#   "type": "NORP",
#   "start_char": 149,
#   "end_char": 156
# }, {
#   "text": "Egypt,",
#   "type": "NORP",
#   "start_char": 163,
#   "end_char": 169
# }, {
#   "text": "Trinitarian",
#   "type": "NORP",
#   "start_char": 506,
#   "end_char": 517
# }, {
#   "text": "Alexandria;",
#   "type": "GPE",
#   "start_char": 625,
#   "end_char": 636
# }, {
#   "text": "East",
#   "type": "LOC",
#   "start_char": 764,
#   "end_char": 768
# }]
# [{
#   "text": "Arius",
#   "type": "PERSON",
#   "start_char": 121,
#   "end_char": 126
# }, {
#   "text": "Arius",
#   "type": "PERSON",
#   "start_char": 149,
#   "end_char": 154
# }]
# []
# [{
#   "text": "Alexander",
#   "type": "PERSON",
#   "start_char": 20,
#   "end_char": 29
# }]
# []
# []
# [{
#   "text": "Arius",
#   "type": "PERSON",
#   "start_char": 17,
#   "end_char": 22
# }]
# [{
#   "text": "two",
#   "type": "CARDINAL",
#   "start_char": 42,
#   "end_char": 45
# }, {
#   "text": "Egypt,",
#   "type": "ORG",
#   "start_char": 57,
#   "end_char": 63
# }, {
#   "text": "seven",
#   "type": "CARDINAL",
#   "start_char": 64,
#   "end_char": 69
# }, {
#   "text": "twelve",
#   "type": "CARDINAL",
#   "start_char": 82,
#   "end_char": 88
# }, {
#   "text": "seven hundred",
#   "type": "CARDINAL",
#   "start_char": 138,
#   "end_char": 151
# }]
# [{
#   "text": "Asia",
#   "type": "LOC",
#   "start_char": 35,
#   "end_char": 39
# }, {
#   "text": "Eusebius",
#   "type": "PERSON",
#   "start_char": 118,
#   "end_char": 126
# }, {
#   "text": "Christian",
#   "type": "NORP",
#   "start_char": 164,
#   "end_char": 173
# }, {
#   "text": "Eusebius",
#   "type": "PERSON",
#   "start_char": 191,
#   "end_char": 199
# }, {
#   "text": "Nicomedia,",
#   "type": "ORG",
#   "start_char": 203,
#   "end_char": 213
# }]
# [{
#   "text": "Palestine",
#   "type": "GPE",
#   "start_char": 10,
#   "end_char": 19
# }, {
#   "text": "Bithynia",
#   "type": "GPE",
#   "start_char": 24,
#   "end_char": 32
# }, {
#   "text": "six",
#   "type": "CARDINAL",
#   "start_char": 184,
#   "end_char": 187
# }, {
#   "text": "the general council of Nice.",
#   "type": "ORG",
#   "start_char": 240,
#   "end_char": 268
# }, {
#   "text": "Three",
#   "type": "CARDINAL",
#   "start_char": 269,
#   "end_char": 274
# }]
# [{
#   "text": "Christian",
#   "type": "NORP",
#   "start_char": 26,
#   "end_char": 35
# }, {
#   "text": "three",
#   "type": "CARDINAL",
#   "start_char": 158,
#   "end_char": 163
# }]
# [{
#   "text": "Arianism",
#   "type": "PERSON",
#   "start_char": 5,
#   "end_char": 13
# }]
# []
# [{
#   "text": "first",
#   "type": "ORDINAL",
#   "start_char": 17,
#   "end_char": 22
# }, {
#   "text": "Arius",
#   "type": "PERSON",
#   "start_char": 59,
#   "end_char": 64
# }]
# []
# [{
#   "text": "Son the Almighty Father",
#   "type": "PERSON",
#   "start_char": 22,
#   "end_char": 45
# }]
# [{
#   "text": "Roman",
#   "type": "NORP",
#   "start_char": 202,
#   "end_char": 207
# }, {
#   "text": "Caesar",
#   "type": "PERSON",
#   "start_char": 255,
#   "end_char": 261
# }, {
#   "text": "the will of his Father",
#   "type": "PERSON",
#   "start_char": 321,
#   "end_char": 343
# }]
# []
# [{
#   "text": "second",
#   "type": "ORDINAL",
#   "start_char": 7,
#   "end_char": 13
# }, {
#   "text": "Three",
#   "type": "CARDINAL",
#   "start_char": 153,
#   "end_char": 158
# }, {
#   "text": "three",
#   "type": "CARDINAL",
#   "start_char": 202,
#   "end_char": 207
# }]
# [{
#   "text": "three",
#   "type": "CARDINAL",
#   "start_char": 57,
#   "end_char": 62
# }]
# []
# []
# []
# [{
#   "text": "Three",
#   "type": "CARDINAL",
#   "start_char": 0,
#   "end_char": 5
# }]
# []
# []
# [{
#   "text": "Jesus",
#   "type": "PERSON",
#   "start_char": 146,
#   "end_char": 151
# }]
# [{
#   "text": "Sabellian",
#   "type": "PERSON",
#   "start_char": 86,
#   "end_char": 95
# }, {
#   "text": "Ebionite",
#   "type": "NORP",
#   "start_char": 111,
#   "end_char": 119
# }, {
#   "text": "Council of Nice, A.D",
#   "type": "ORG",
#   "start_char": 220,
#   "end_char": 240
# }]
# [{
#   "text": "325",
#   "type": "CARDINAL",
#   "start_char": 0,
#   "end_char": 3
# }]
# [{
#   "text": "the council of Nice(55)",
#   "type": "ORG",
#   "start_char": 18,
#   "end_char": 41
# }, {
#   "text": "Arius",
#   "type": "PERSON",
#   "start_char": 115,
#   "end_char": 120
# }, {
#   "text": "two",
#   "type": "CARDINAL",
#   "start_char": 283,
#   "end_char": 286
# }]
# [{
#   "text": "Arians",
#   "type": "PERSON",
#   "start_char": 4,
#   "end_char": 10
# }]
# [{
#   "text": "Christian",
#   "type": "NORP",
#   "start_char": 33,
#   "end_char": 42
# }]
# [{
#   "text": "Arians",
#   "type": "NORP",
#   "start_char": 183,
#   "end_char": 189
# }]
# [{
#   "text": "Eusebius",
#   "type": "PERSON",
#   "start_char": 74,
#   "end_char": 82
# }]
# [{
#   "text": "Ambrose,",
#   "type": "PERSON",
#   "start_char": 150,
#   "end_char": 158
# }]
# [{
#   "text": "The consubstantiality of the Father and the Son",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 47
# }, {
#   "text": "the council of Nice,",
#   "type": "ORG",
#   "start_char": 67,
#   "end_char": 87
# }, {
#   "text": "Christian",
#   "type": "NORP",
#   "start_char": 154,
#   "end_char": 163
# }, {
#   "text": "the Greek, the Latin, the Oriental,",
#   "type": "PERSON",
#   "start_char": 188,
#   "end_char": 223
# }, {
#   "text": "Protestant",
#   "type": "NORP",
#   "start_char": 232,
#   "end_char": 242
# }]
# []
# [{
#   "text": "two",
#   "type": "CARDINAL",
#   "start_char": 31,
#   "end_char": 34
# }, {
#   "text": "Tritheists",
#   "type": "NORP",
#   "start_char": 106,
#   "end_char": 116
# }, {
#   "text": "Sabellians",
#   "type": "PERSON",
#   "start_char": 128,
#   "end_char": 138
# }]
# []
# []
# [{
#   "text": "Sabellian",
#   "type": "NORP",
#   "start_char": 4,
#   "end_char": 13
# }, {
#   "text": "about fifty years",
#   "type": "DATE",
#   "start_char": 28,
#   "end_char": 45
# }, {
#   "text": "Antioch(57)",
#   "type": "PERSON",
#   "start_char": 81,
#   "end_char": 92
# }]
# [{
#   "text": "Arian",
#   "type": "NORP",
#   "start_char": 39,
#   "end_char": 44
# }, {
#   "text": "Athanasius,",
#   "type": "PERSON",
#   "start_char": 65,
#   "end_char": 76
# }, {
#   "text": "Gregory Nazianzen,",
#   "type": "PERSON",
#   "start_char": 89,
#   "end_char": 107
# }, {
#   "text": "Nicene",
#   "type": "PERSON",
#   "start_char": 188,
#   "end_char": 194
# }, {
#   "text": "three",
#   "type": "CARDINAL",
#   "start_char": 368,
#   "end_char": 373
# }, {
#   "text": "Father,",
#   "type": "PERSON",
#   "start_char": 687,
#   "end_char": 694
# }]
# []
# []
# []
# [{
#   "text": "Athanasius",
#   "type": "PERSON",
#   "start_char": 12,
#   "end_char": 22
# }, {
#   "text": "Arians,(61)",
#   "type": "PERSON",
#   "start_char": 95,
#   "end_char": 106
# }, {
#   "text": "twenty years",
#   "type": "DATE",
#   "start_char": 129,
#   "end_char": 141
# }, {
#   "text": "the Sabellianism of Marcellus of Ancyra;",
#   "type": "PERSON",
#   "start_char": 142,
#   "end_char": 182
# }, {
#   "text": "Arian Creeds",
#   "type": "PERSON",
#   "start_char": 354,
#   "end_char": 366
# }]
# [{
#   "text": "Arians",
#   "type": "PERSON",
#   "start_char": 49,
#   "end_char": 55
# }]
# []
# [{
#   "text": "Arian",
#   "type": "NORP",
#   "start_char": 36,
#   "end_char": 41
# }, {
#   "text": "eighteen",
#   "type": "CARDINAL",
#   "start_char": 355,
#   "end_char": 363
# }]
# [{
#   "text": "Hilary,",
#   "type": "PERSON",
#   "start_char": 12,
#   "end_char": 19
# }, {
#   "text": "Oriental",
#   "type": "NORP",
#   "start_char": 145,
#   "end_char": 153
# }, {
#   "text": "ten",
#   "type": "CARDINAL",
#   "start_char": 203,
#   "end_char": 206
# }, {
#   "text": "Asia",
#   "type": "LOC",
#   "start_char": 220,
#   "end_char": 224
# }, {
#   "text": "Poitiers",
#   "type": "GPE",
#   "start_char": 593,
#   "end_char": 601
# }, {
#   "text": "Christian",
#   "type": "NORP",
#   "start_char": 640,
#   "end_char": 649
# }]
# [{
#   "text": "Arian Sects",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 11
# }]
# [{
#   "text": "eighteen",
#   "type": "CARDINAL",
#   "start_char": 28,
#   "end_char": 36
# }, {
#   "text": "Arius",
#   "type": "PERSON",
#   "start_char": 129,
#   "end_char": 134
# }]
# []
# [{
#   "text": "One",
#   "type": "CARDINAL",
#   "start_char": 0,
#   "end_char": 3
# }, {
#   "text": "Arian",
#   "type": "NORP",
#   "start_char": 45,
#   "end_char": 50
# }, {
#   "text": "three",
#   "type": "CARDINAL",
#   "start_char": 135,
#   "end_char": 140
# }, {
#   "text": "the Homoousion of the Nicene",
#   "type": "PERSON",
#   "start_char": 196,
#   "end_char": 224
# }]
# [{
#   "text": "Arius,",
#   "type": "PERSON",
#   "start_char": 167,
#   "end_char": 173
# }]
# [{
#   "text": "Atheist",
#   "type": "NORP",
#   "start_char": 119,
#   "end_char": 126
# }]
# []
# [{
#   "text": "Aristotle,",
#   "type": "GPE",
#   "start_char": 319,
#   "end_char": 329
# }, {
#   "text": "Aetius",
#   "type": "ORG",
#   "start_char": 341,
#   "end_char": 347
# }]
# [{
#   "text": "Arian",
#   "type": "NORP",
#   "start_char": 43,
#   "end_char": 48
# }]
# []
# [{
#   "text": "the Father and the Son;",
#   "type": "PERSON",
#   "start_char": 95,
#   "end_char": 118
# }]
# [{
#   "text": "Arians",
#   "type": "NORP",
#   "start_char": 11,
#   "end_char": 17
# }, {
#   "text": "Eusebian",
#   "type": "GPE",
#   "start_char": 133,
#   "end_char": 141
# }, {
#   "text": "East",
#   "type": "LOC",
#   "start_char": 198,
#   "end_char": 202
# }]
# [{
#   "text": "Aetius;",
#   "type": "NORP",
#   "start_char": 61,
#   "end_char": 68
# }, {
#   "text": "the Scriptures, that the Son",
#   "type": "WORK_OF_ART",
#   "start_char": 135,
#   "end_char": 163
# }]
# []
# []
# [{
#   "text": "Asia;",
#   "type": "GPE",
#   "start_char": 112,
#   "end_char": 117
# }, {
#   "text": "Seleucia,",
#   "type": "PERSON",
#   "start_char": 188,
#   "end_char": 197
# }, {
#   "text": "one hundred and five to forty-three",
#   "type": "CARDINAL",
#   "start_char": 255,
#   "end_char": 290
# }]
# [{
#   "text": "Greek",
#   "type": "NORP",
#   "start_char": 4,
#   "end_char": 9
# }, {
#   "text": "Homoousians",
#   "type": "NORP",
#   "start_char": 249,
#   "end_char": 260
# }, {
#   "text": "Homoiousians",
#   "type": "NORP",
#   "start_char": 269,
#   "end_char": 281
# }]
# [{
#   "text": "Catholics",
#   "type": "NORP",
#   "start_char": 340,
#   "end_char": 349
# }]
# [{
#   "text": "The bishop of Poitiers,",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 23
# }, {
#   "text": "Phrygian",
#   "type": "NORP",
#   "start_char": 35,
#   "end_char": 43
# }]
# [{
#   "text": "Semi-Arians,",
#   "type": "NORP",
#   "start_char": 129,
#   "end_char": 141
# }, {
#   "text": "Western",
#   "type": "NORP",
#   "start_char": 242,
#   "end_char": 249
# }, {
#   "text": "Latin",
#   "type": "NORP",
#   "start_char": 253,
#   "end_char": 258
# }, {
#   "text": "Egypt",
#   "type": "GPE",
#   "start_char": 283,
#   "end_char": 288
# }, {
#   "text": "Asia,",
#   "type": "GPE",
#   "start_char": 293,
#   "end_char": 298
# }, {
#   "text": "Greeks,",
#   "type": "NORP",
#   "start_char": 348,
#   "end_char": 355
# }, {
#   "text": "Arian",
#   "type": "NORP",
#   "start_char": 392,
#   "end_char": 397
# }]
# [{
#   "text": "East",
#   "type": "LOC",
#   "start_char": 149,
#   "end_char": 153
# }]
# [{
#   "text": "West",
#   "type": "LOC",
#   "start_char": 23,
#   "end_char": 27
# }, {
#   "text": "Gallican",
#   "type": "NORP",
#   "start_char": 236,
#   "end_char": 244
# }, {
#   "text": "Hilary",
#   "type": "PERSON",
#   "start_char": 258,
#   "end_char": 264
# }, {
#   "text": "thirty years",
#   "type": "DATE",
#   "start_char": 280,
#   "end_char": 292
# }, {
#   "text": "first",
#   "type": "ORDINAL",
#   "start_char": 303,
#   "end_char": 308
# }, {
#   "text": "Nicene",
#   "type": "PERSON",
#   "start_char": 354,
#   "end_char": 360
# }, {
#   "text": "Latins",
#   "type": "NORP",
#   "start_char": 376,
#   "end_char": 382
# }]
# [{
#   "text": "Greek",
#   "type": "NORP",
#   "start_char": 113,
#   "end_char": 118
# }, {
#   "text": "Gospel",
#   "type": "WORK_OF_ART",
#   "start_char": 218,
#   "end_char": 224
# }, {
#   "text": "Christian",
#   "type": "NORP",
#   "start_char": 275,
#   "end_char": 284
# }, {
#   "text": "Latin",
#   "type": "NORP",
#   "start_char": 337,
#   "end_char": 342
# }, {
#   "text": "Arian",
#   "type": "NORP",
#   "start_char": 593,
#   "end_char": 598
# }, {
#   "text": "Roman",
#   "type": "NORP",
#   "start_char": 736,
#   "end_char": 741
# }]
# [{
#   "text": "Council of Rimi, A.D",
#   "type": "ORG",
#   "start_char": 0,
#   "end_char": 20
# }]
# [{
#   "text": "Rimini,",
#   "type": "PERSON",
#   "start_char": 79,
#   "end_char": 86
# }, {
#   "text": "the council of Nice,",
#   "type": "ORG",
#   "start_char": 114,
#   "end_char": 134
# }, {
#   "text": "four hundred",
#   "type": "CARDINAL",
#   "start_char": 166,
#   "end_char": 178
# }, {
#   "text": "Italy, Africa,",
#   "type": "ORG",
#   "start_char": 190,
#   "end_char": 204
# }, {
#   "text": "Spain, Gaul, Britain,",
#   "type": "PERSON",
#   "start_char": 205,
#   "end_char": 226
# }, {
#   "text": "Illyricum",
#   "type": "GPE",
#   "start_char": 231,
#   "end_char": 240
# }]
# [{
#   "text": "first",
#   "type": "ORDINAL",
#   "start_char": 9,
#   "end_char": 14
# }, {
#   "text": "four",
#   "type": "CARDINAL",
#   "start_char": 45,
#   "end_char": 49
# }, {
#   "text": "Arius",
#   "type": "PERSON",
#   "start_char": 147,
#   "end_char": 152
# }]
# [{
#   "text": "Valens",
#   "type": "PERSON",
#   "start_char": 133,
#   "end_char": 139
# }, {
#   "text": "Ursacius,",
#   "type": "PERSON",
#   "start_char": 144,
#   "end_char": 153
# }, {
#   "text": "two",
#   "type": "CARDINAL",
#   "start_char": 154,
#   "end_char": 157
# }, {
#   "text": "Illyricum,",
#   "type": "GPE",
#   "start_char": 169,
#   "end_char": 179
# }, {
#   "text": "Eusebian",
#   "type": "NORP",
#   "start_char": 282,
#   "end_char": 290
# }, {
#   "text": "Latin",
#   "type": "NORP",
#   "start_char": 455,
#   "end_char": 460
# }]
# [{
#   "text": "Rimini",
#   "type": "GPE",
#   "start_char": 15,
#   "end_char": 21
# }, {
#   "text": "Homoousion",
#   "type": "PERSON",
#   "start_char": 207,
#   "end_char": 217
# }]
# [{
#   "text": "Jerom,",
#   "type": "PERSON",
#   "start_char": 43,
#   "end_char": 49
# }, {
#   "text": "Latin",
#   "type": "NORP",
#   "start_char": 123,
#   "end_char": 128
# }]
# [{
#   "text": "Homoousian",
#   "type": "NORP",
#   "start_char": 79,
#   "end_char": 89
# }, {
#   "text": "Arian",
#   "type": "NORP",
#   "start_char": 236,
#   "end_char": 241
# }, {
#   "text": "Christianity",
#   "type": "NORP",
#   "start_char": 383,
#   "end_char": 395
# }, {
#   "text": "Constantine",
#   "type": "PERSON",
#   "start_char": 416,
#   "end_char": 427
# }]
# [{
#   "text": "the King of Heaven",
#   "type": "PERSON",
#   "start_char": 230,
#   "end_char": 248
# }]
# [{
#   "text": "324",
#   "type": "CARDINAL",
#   "start_char": 0,
#   "end_char": 3
# }, {
#   "text": "East",
#   "type": "LOC",
#   "start_char": 70,
#   "end_char": 74
# }]
# [{
#   "text": "Alexander",
#   "type": "PERSON",
#   "start_char": 126,
#   "end_char": 135
# }, {
#   "text": "Arius,",
#   "type": "PERSON",
#   "start_char": 143,
#   "end_char": 149
# }]
# []
# [{
#   "text": "Christian",
#   "type": "NORP",
#   "start_char": 20,
#   "end_char": 29
# }, {
#   "text": "Alexandria",
#   "type": "GPE",
#   "start_char": 201,
#   "end_char": 211
# }, {
#   "text": "Greek",
#   "type": "NORP",
#   "start_char": 231,
#   "end_char": 236
# }]
# [{
#   "text": "Constantine",
#   "type": "PERSON",
#   "start_char": 190,
#   "end_char": 201
# }]
# []
# []
# [{
#   "text": "three hundred",
#   "type": "CARDINAL",
#   "start_char": 251,
#   "end_char": 264
# }]
# []
# [{
#   "text": "Constantine,(78)",
#   "type": "PERSON",
#   "start_char": 86,
#   "end_char": 102
# }, {
#   "text": "Roman",
#   "type": "NORP",
#   "start_char": 105,
#   "end_char": 110
# }, {
#   "text": "Greek",
#   "type": "NORP",
#   "start_char": 292,
#   "end_char": 297
# }]
# [{
#   "text": "Osius,",
#   "type": "PERSON",
#   "start_char": 32,
#   "end_char": 38
# }, {
#   "text": "Nice,",
#   "type": "PERSON",
#   "start_char": 86,
#   "end_char": 91
# }, {
#   "text": "Eusebius",
#   "type": "PERSON",
#   "start_char": 195,
#   "end_char": 203
# }]
# [{
#   "text": "Nicene",
#   "type": "PERSON",
#   "start_char": 4,
#   "end_char": 10
# }, {
#   "text": "Constantine;",
#   "type": "PERSON",
#   "start_char": 33,
#   "end_char": 45
# }]
# [{
#   "text": "Eusebius",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 8
# }, {
#   "text": "Casarea",
#   "type": "GPE",
#   "start_char": 12,
#   "end_char": 19
# }, {
#   "text": "the Nicomedian Eusebius",
#   "type": "WORK_OF_ART",
#   "start_char": 114,
#   "end_char": 137
# }, {
#   "text": "about three months",
#   "type": "DATE",
#   "start_char": 159,
#   "end_char": 177
# }, {
#   "text": "Arian",
#   "type": "NORP",
#   "start_char": 223,
#   "end_char": 228
# }, {
#   "text": "Arius",
#   "type": "PERSON",
#   "start_char": 241,
#   "end_char": 246
# }, {
#   "text": "one",
#   "type": "CARDINAL",
#   "start_char": 265,
#   "end_char": 268
# }, {
#   "text": "Illyricum;",
#   "type": "GPE",
#   "start_char": 296,
#   "end_char": 306
# }, {
#   "text": "Porphyrians;",
#   "type": "PERSON",
#   "start_char": 378,
#   "end_char": 390
# }]
# [{
#   "text": "Christ.(82)",
#   "type": "PERSON",
#   "start_char": 198,
#   "end_char": 209
# }]
# [{
#   "text": "three years",
#   "type": "DATE",
#   "start_char": 95,
#   "end_char": 106
# }]
# [{
#   "text": "Eusebius,",
#   "type": "PERSON",
#   "start_char": 30,
#   "end_char": 39
# }]
# [{
#   "text": "Arius",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 5
# }]
# [{
#   "text": "Jerusalem;",
#   "type": "GPE",
#   "start_char": 39,
#   "end_char": 49
# }, {
#   "text": "Constantinople",
#   "type": "GPE",
#   "start_char": 212,
#   "end_char": 226
# }]
# [{
#   "text": "the same day",
#   "type": "DATE",
#   "start_char": 3,
#   "end_char": 15
# }, {
#   "text": "Arius,",
#   "type": "PERSON",
#   "start_char": 56,
#   "end_char": 62
# }]
# [{
#   "text": "three",
#   "type": "CARDINAL",
#   "start_char": 9,
#   "end_char": 14
# }, {
#   "text": "Athanasius",
#   "type": "PERSON",
#   "start_char": 51,
#   "end_char": 61
# }, {
#   "text": "Alexandria, Eustathius",
#   "type": "PERSON",
#   "start_char": 65,
#   "end_char": 87
# }, {
#   "text": "Antioch,",
#   "type": "GPE",
#   "start_char": 91,
#   "end_char": 99
# }, {
#   "text": "Paul",
#   "type": "PERSON",
#   "start_char": 104,
#   "end_char": 108
# }, {
#   "text": "first",
#   "type": "ORDINAL",
#   "start_char": 262,
#   "end_char": 267
# }, {
#   "text": "Christian",
#   "type": "NORP",
#   "start_char": 275,
#   "end_char": 284
# }, {
#   "text": "Arian",
#   "type": "NORP",
#   "start_char": 371,
#   "end_char": 376
# }, {
#   "text": "Nicomedia",
#   "type": "GPE",
#   "start_char": 387,
#   "end_char": 396
# }]
# [{
#   "text": "Constantine",
#   "type": "PERSON",
#   "start_char": 33,
#   "end_char": 44
# }]
# [{
#   "text": "Arius,",
#   "type": "PERSON",
#   "start_char": 224,
#   "end_char": 230
# }, {
#   "text": "Athanasius,",
#   "type": "PERSON",
#   "start_char": 246,
#   "end_char": 257
# }, {
#   "text": "Nice",
#   "type": "GPE",
#   "start_char": 293,
#   "end_char": 297
# }, {
#   "text": "Christian",
#   "type": "NORP",
#   "start_char": 320,
#   "end_char": 329
# }, {
#   "text": "Constantius",
#   "type": "PERSON",
#   "start_char": 382,
#   "end_char": 393
# }]
# []
# [{
#   "text": "Constantine",
#   "type": "PERSON",
#   "start_char": 12,
#   "end_char": 23
# }, {
#   "text": "Trinitarian",
#   "type": "NORP",
#   "start_char": 319,
#   "end_char": 330
# }, {
#   "text": "Constantius,",
#   "type": "PERSON",
#   "start_char": 394,
#   "end_char": 406
# }, {
#   "text": "East,",
#   "type": "NORP",
#   "start_char": 442,
#   "end_char": 447
# }]
# [{
#   "text": "The Arian",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 9
# }]
# [{
#   "text": "Constantius",
#   "type": "PERSON",
#   "start_char": 233,
#   "end_char": 244
# }, {
#   "text": "Eusebian",
#   "type": "NORP",
#   "start_char": 274,
#   "end_char": 282
# }, {
#   "text": "Magnentius",
#   "type": "PERSON",
#   "start_char": 394,
#   "end_char": 404
# }, {
#   "text": "Arianism",
#   "type": "PERSON",
#   "start_char": 496,
#   "end_char": 504
# }]
# [{
#   "text": "two",
#   "type": "CARDINAL",
#   "start_char": 10,
#   "end_char": 13
# }, {
#   "text": "Mursa,",
#   "type": "PERSON",
#   "start_char": 51,
#   "end_char": 57
# }, {
#   "text": "two",
#   "type": "CARDINAL",
#   "start_char": 78,
#   "end_char": 81
# }, {
#   "text": "war, the son of Constantine",
#   "type": "PERSON",
#   "start_char": 115,
#   "end_char": 142
# }]
# [{
#   "text": "Arian",
#   "type": "NORP",
#   "start_char": 37,
#   "end_char": 42
# }]
# [{
#   "text": "Valens",
#   "type": "PERSON",
#   "start_char": 165,
#   "end_char": 171
# }, {
#   "text": "Gallic",
#   "type": "NORP",
#   "start_char": 193,
#   "end_char": 199
# }]
# [{
#   "text": "Mursa,",
#   "type": "PERSON",
#   "start_char": 90,
#   "end_char": 96
# }]
# [{
#   "text": "Arians,",
#   "type": "NORP",
#   "start_char": 9,
#   "end_char": 16
# }, {
#   "text": "Constantius,",
#   "type": "PERSON",
#   "start_char": 60,
#   "end_char": 72
# }, {
#   "text": "Cyril,",
#   "type": "PERSON",
#   "start_char": 120,
#   "end_char": 126
# }, {
#   "text": "Jerusalem,",
#   "type": "GPE",
#   "start_char": 137,
#   "end_char": 147
# }, {
#   "text": "Pentecost,",
#   "type": "EVENT",
#   "start_char": 272,
#   "end_char": 282
# }, {
#   "text": "about the third hour",
#   "type": "TIME",
#   "start_char": 283,
#   "end_char": 303
# }, {
#   "text": "the Mount of Olives,",
#   "type": "LOC",
#   "start_char": 334,
#   "end_char": 354
# }]
# [{
#   "text": "Arian",
#   "type": "NORP",
#   "start_char": 61,
#   "end_char": 66
# }, {
#   "text": "two",
#   "type": "CARDINAL",
#   "start_char": 131,
#   "end_char": 134
# }, {
#   "text": "Arian Councils",
#   "type": "ORG",
#   "start_char": 297,
#   "end_char": 311
# }, {
#   "text": "Ammianus,",
#   "type": "PERSON",
#   "start_char": 490,
#   "end_char": 499
# }]
# [{
#   "text": "Constantius",
#   "type": "GPE",
#   "start_char": 79,
#   "end_char": 90
# }]
# [{
#   "text": "Arles, Milan, Sirmium,",
#   "type": "FAC",
#   "start_char": 125,
#   "end_char": 147
# }, {
#   "text": "Constantinople,",
#   "type": "GPE",
#   "start_char": 152,
#   "end_char": 167
# }, {
#   "text": "Nice,",
#   "type": "PERSON",
#   "start_char": 361,
#   "end_char": 366
# }, {
#   "text": "The eunuchs, the women,",
#   "type": "PERSON",
#   "start_char": 460,
#   "end_char": 483
# }, {
#   "text": "Homoousion;",
#   "type": "NORP",
#   "start_char": 607,
#   "end_char": 618
# }, {
#   "text": "Aetius",
#   "type": "PERSON",
#   "start_char": 674,
#   "end_char": 680
# }]
# [{
#   "text": "Gallus;",
#   "type": "PERSON",
#   "start_char": 85,
#   "end_char": 92
# }, {
#   "text": "Imperial",
#   "type": "ORG",
#   "start_char": 120,
#   "end_char": 128
# }, {
#   "text": "Antioch",
#   "type": "GPE",
#   "start_char": 165,
#   "end_char": 172
# }]
# [{
#   "text": "Arian",
#   "type": "NORP",
#   "start_char": 303,
#   "end_char": 308
# }, {
#   "text": "Semi-Arian",
#   "type": "NORP",
#   "start_char": 313,
#   "end_char": 323
# }]
# []
# []
# [{
#   "text": "Gaul, Italy, Illyricum,",
#   "type": "ORG",
#   "start_char": 105,
#   "end_char": 128
# }, {
#   "text": "Asia,",
#   "type": "GPE",
#   "start_char": 133,
#   "end_char": 138
# }, {
#   "text": "Arians,",
#   "type": "NORP",
#   "start_char": 205,
#   "end_char": 212
# }]
# [{
#   "text": "Nicomedia,",
#   "type": "GPE",
#   "start_char": 30,
#   "end_char": 40
# }]
# [{
#   "text": "East",
#   "type": "LOC",
#   "start_char": 19,
#   "end_char": 23
# }, {
#   "text": "Isauria;",
#   "type": "GPE",
#   "start_char": 62,
#   "end_char": 70
# }, {
#   "text": "West",
#   "type": "LOC",
#   "start_char": 90,
#   "end_char": 94
# }, {
#   "text": "Rimini,",
#   "type": "GPE",
#   "start_char": 123,
#   "end_char": 130
# }, {
#   "text": "Hadriatic,",
#   "type": "LOC",
#   "start_char": 151,
#   "end_char": 161
# }, {
#   "text": "two",
#   "type": "CARDINAL",
#   "start_char": 177,
#   "end_char": 180
# }, {
#   "text": "three",
#   "type": "CARDINAL",
#   "start_char": 184,
#   "end_char": 189
# }]
# [{
#   "text": "four days",
#   "type": "DATE",
#   "start_char": 37,
#   "end_char": 46
# }]
# [{
#   "text": "West",
#   "type": "LOC",
#   "start_char": 19,
#   "end_char": 23
# }, {
#   "text": "seventh",
#   "type": "ORDINAL",
#   "start_char": 48,
#   "end_char": 55
# }, {
#   "text": "Praetorian",
#   "type": "NORP",
#   "start_char": 75,
#   "end_char": 85
# }, {
#   "text": "fifteen",
#   "type": "CARDINAL",
#   "start_char": 246,
#   "end_char": 253
# }]
# [{
#   "text": "Valens",
#   "type": "PERSON",
#   "start_char": 74,
#   "end_char": 80
# }, {
#   "text": "Ursacius,",
#   "type": "PERSON",
#   "start_char": 85,
#   "end_char": 94
# }, {
#   "text": "Rimini",
#   "type": "GPE",
#   "start_char": 235,
#   "end_char": 241
# }]
# [{
#   "text": "East",
#   "type": "LOC",
#   "start_char": 20,
#   "end_char": 24
# }, {
#   "text": "West",
#   "type": "LOC",
#   "start_char": 36,
#   "end_char": 40
# }, {
#   "text": "Constantinople,",
#   "type": "GPE",
#   "start_char": 79,
#   "end_char": 94
# }, {
#   "text": "the Son of God.(95)",
#   "type": "PERSON",
#   "start_char": 251,
#   "end_char": 270
# }, {
#   "text": "Constantius",
#   "type": "PERSON",
#   "start_char": 432,
#   "end_char": 443
# }, {
#   "text": "Athanasius",
#   "type": "PERSON",
#   "start_char": 553,
#   "end_char": 563
# }]
# [{
#   "text": "Athanasius",
#   "type": "PERSON",
#   "start_char": 21,
#   "end_char": 31
# }, {
#   "text": "Trinity,",
#   "type": "NORP",
#   "start_char": 95,
#   "end_char": 103
# }]
# [{
#   "text": "Alexander,",
#   "type": "PERSON",
#   "start_char": 26,
#   "end_char": 36
# }, {
#   "text": "Arian",
#   "type": "NORP",
#   "start_char": 89,
#   "end_char": 94
# }, {
#   "text": "Nicene",
#   "type": "NORP",
#   "start_char": 200,
#   "end_char": 206
# }]
# [{
#   "text": "five months",
#   "type": "DATE",
#   "start_char": 99,
#   "end_char": 110
# }, {
#   "text": "Nice the deacon Athanasius",
#   "type": "PERSON",
#   "start_char": 133,
#   "end_char": 159
# }, {
#   "text": "Egypt",
#   "type": "GPE",
#   "start_char": 203,
#   "end_char": 208
# }]
# [{
#   "text": "Arianism",
#   "type": "NORP",
#   "start_char": 136,
#   "end_char": 144
# }]
# [{
#   "text": "Five",
#   "type": "CARDINAL",
#   "start_char": 0,
#   "end_char": 4
# }, {
#   "text": "Athanasius",
#   "type": "PERSON",
#   "start_char": 15,
#   "end_char": 25
# }, {
#   "text": "twenty years",
#   "type": "DATE",
#   "start_char": 52,
#   "end_char": 64
# }, {
#   "text": "Roman",
#   "type": "NORP",
#   "start_char": 135,
#   "end_char": 140
# }]
# [{
#   "text": "Alexandria",
#   "type": "GPE",
#   "start_char": 52,
#   "end_char": 62
# }, {
#   "text": "Athanasius",
#   "type": "PERSON",
#   "start_char": 189,
#   "end_char": 199
# }, {
#   "text": "Constantine,",
#   "type": "NORP",
#   "start_char": 322,
#   "end_char": 334
# }]
# [{
#   "text": "Eusebius",
#   "type": "PERSON",
#   "start_char": 63,
#   "end_char": 71
# }, {
#   "text": "Gregory",
#   "type": "PERSON",
#   "start_char": 159,
#   "end_char": 166
# }, {
#   "text": "Basil;",
#   "type": "PERSON",
#   "start_char": 170,
#   "end_char": 176
# }, {
#   "text": "Egypt",
#   "type": "GPE",
#   "start_char": 205,
#   "end_char": 210
# }]
# [{
#   "text": "one",
#   "type": "CARDINAL",
#   "start_char": 53,
#   "end_char": 56
# }, {
#   "text": "Christian",
#   "type": "NORP",
#   "start_char": 93,
#   "end_char": 102
# }, {
#   "text": "two",
#   "type": "CARDINAL",
#   "start_char": 144,
#   "end_char": 147
# }]
# [{
#   "text": "Athanasius,",
#   "type": "PERSON",
#   "start_char": 124,
#   "end_char": 135
# }, {
#   "text": "Athanasius",
#   "type": "PERSON",
#   "start_char": 245,
#   "end_char": 255
# }, {
#   "text": "first",
#   "type": "ORDINAL",
#   "start_char": 404,
#   "end_char": 409
# }]
# []
# [{
#   "text": "Alexandria",
#   "type": "GPE",
#   "start_char": 18,
#   "end_char": 28
# }]
# [{
#   "text": "Athanasius",
#   "type": "PERSON",
#   "start_char": 16,
#   "end_char": 26
# }]
# [{
#   "text": "Alexandrians",
#   "type": "NORP",
#   "start_char": 4,
#   "end_char": 16
# }]
# [{
#   "text": "hundred",
#   "type": "CARDINAL",
#   "start_char": 130,
#   "end_char": 137
# }, {
#   "text": "Egypt",
#   "type": "GPE",
#   "start_char": 149,
#   "end_char": 154
# }, {
#   "text": "Athanasius",
#   "type": "PERSON",
#   "start_char": 200,
#   "end_char": 210
# }]
# [{
#   "text": "Nile",
#   "type": "LOC",
#   "start_char": 149,
#   "end_char": 153
# }, {
#   "text": "Ethiopia;",
#   "type": "GPE",
#   "start_char": 173,
#   "end_char": 182
# }, {
#   "text": "Athanasius",
#   "type": "PERSON",
#   "start_char": 416,
#   "end_char": 426
# }]
# []
# [{
#   "text": "330",
#   "type": "CARDINAL",
#   "start_char": 0,
#   "end_char": 3
# }, {
#   "text": "Egypt",
#   "type": "GPE",
#   "start_char": 32,
#   "end_char": 37
# }, {
#   "text": "Arius",
#   "type": "PERSON",
#   "start_char": 113,
#   "end_char": 118
# }, {
#   "text": "Athanasius",
#   "type": "PERSON",
#   "start_char": 271,
#   "end_char": 281
# }]
# [{
#   "text": "the Nicene council",
#   "type": "ORG",
#   "start_char": 174,
#   "end_char": 192
# }, {
#   "text": "Meletius.(102) Athanasius",
#   "type": "PERSON",
#   "start_char": 226,
#   "end_char": 251
# }, {
#   "text": "one",
#   "type": "CARDINAL",
#   "start_char": 477,
#   "end_char": 480
# }, {
#   "text": "six",
#   "type": "CARDINAL",
#   "start_char": 547,
#   "end_char": 550
# }, {
#   "text": "Arsenius,",
#   "type": "PERSON",
#   "start_char": 578,
#   "end_char": 587
# }, {
#   "text": "seventh",
#   "type": "ORDINAL",
#   "start_char": 590,
#   "end_char": 597
# }, {
#   "text": "Constantine",
#   "type": "PERSON",
#   "start_char": 777,
#   "end_char": 788
# }, {
#   "text": "Dalmatius,",
#   "type": "PERSON",
#   "start_char": 804,
#   "end_char": 814
# }, {
#   "text": "Caesarea",
#   "type": "GPE",
#   "start_char": 865,
#   "end_char": 873
# }, {
#   "text": "Tyre",
#   "type": "GPE",
#   "start_char": 878,
#   "end_char": 882
# }, {
#   "text": "East",
#   "type": "LOC",
#   "start_char": 934,
#   "end_char": 938
# }, {
#   "text": "Athanasius",
#   "type": "PERSON",
#   "start_char": 977,
#   "end_char": 987
# }, {
#   "text": "Jerusalem",
#   "type": "GPE",
#   "start_char": 1062,
#   "end_char": 1071
# }]
# []
# [{
#   "text": "fifty",
#   "type": "CARDINAL",
#   "start_char": 325,
#   "end_char": 330
# }, {
#   "text": "Egyptian",
#   "type": "NORP",
#   "start_char": 331,
#   "end_char": 339
# }, {
#   "text": "Alexandria,",
#   "type": "GPE",
#   "start_char": 362,
#   "end_char": 373
# }, {
#   "text": "Meletians;",
#   "type": "PERSON",
#   "start_char": 416,
#   "end_char": 426
# }, {
#   "text": "Arsenius",
#   "type": "PERSON",
#   "start_char": 431,
#   "end_char": 439
# }]
# [{
#   "text": "Tyre",
#   "type": "GPE",
#   "start_char": 13,
#   "end_char": 17
# }, {
#   "text": "Eusebius",
#   "type": "PERSON",
#   "start_char": 35,
#   "end_char": 43
# }, {
#   "text": "Caesarea,",
#   "type": "GPE",
#   "start_char": 47,
#   "end_char": 56
# }, {
#   "text": "Athanasius,",
#   "type": "PERSON",
#   "start_char": 269,
#   "end_char": 280
# }, {
#   "text": "Arsenius",
#   "type": "NORP",
#   "start_char": 325,
#   "end_char": 333
# }]
# []
# [{
#   "text": "Arians,",
#   "type": "NORP",
#   "start_char": 4,
#   "end_char": 11
# }, {
#   "text": "six",
#   "type": "CARDINAL",
#   "start_char": 214,
#   "end_char": 217
# }, {
#   "text": "Egyptian",
#   "type": "NORP",
#   "start_char": 315,
#   "end_char": 323
# }, {
#   "text": "Alexandria,",
#   "type": "GPE",
#   "start_char": 419,
#   "end_char": 430
# }, {
#   "text": "Egypt",
#   "type": "GPE",
#   "start_char": 537,
#   "end_char": 542
# }]
# [{
#   "text": "Catholic",
#   "type": "NORP",
#   "start_char": 110,
#   "end_char": 118
# }, {
#   "text": "first",
#   "type": "ORDINAL",
#   "start_char": 263,
#   "end_char": 268
# }]
# [{
#   "text": "336",
#   "type": "CARDINAL",
#   "start_char": 0,
#   "end_char": 3
# }, {
#   "text": "Athanasius",
#   "type": "PERSON",
#   "start_char": 126,
#   "end_char": 136
# }]
# [{
#   "text": "Tyre,",
#   "type": "PERSON",
#   "start_char": 166,
#   "end_char": 171
# }, {
#   "text": "Athanasius",
#   "type": "PERSON",
#   "start_char": 344,
#   "end_char": 354
# }, {
#   "text": "Constantine's",
#   "type": "PERSON",
#   "start_char": 400,
#   "end_char": 413
# }, {
#   "text": "Constantinople",
#   "type": "GPE",
#   "start_char": 546,
# ...
#   "end_char": 23
# }, {
#   "text": "Constantius",
#   "type": "PERSON",
#   "start_char": 86,
#   "end_char": 97
# }, {
#   "text": "Rome,",
#   "type": "GPE",
#   "start_char": 106,
#   "end_char": 111
# }, {
#   "text": "Liberius,",
#   "type": "PERSON",
#   "start_char": 421,
#   "end_char": 430
# }]
# [{
#   "text": "two",
#   "type": "CARDINAL",
#   "start_char": 288,
#   "end_char": 291
# }, {
#   "text": "Liberius",
#   "type": "NORP",
#   "start_char": 301,
#   "end_char": 309
# }, {
#   "text": "Felix,",
#   "type": "ORG",
#   "start_char": 314,
#   "end_char": 320
# }]
# [{
#   "text": "Constantius",
#   "type": "PERSON",
#   "start_char": 132,
#   "end_char": 143
# }, {
#   "text": "the Circus of Rome,",
#   "type": "WORK_OF_ART",
#   "start_char": 165,
#   "end_char": 184
# }]
# [{
#   "text": "Circus",
#   "type": "FAC",
#   "start_char": 141,
#   "end_char": 147
# }, {
#   "text": "One",
#   "type": "CARDINAL",
#   "start_char": 222,
#   "end_char": 225
# }, {
#   "text": "One",
#   "type": "CARDINAL",
#   "start_char": 234,
#   "end_char": 237
# }, {
#   "text": "Roman",
#   "type": "NORP",
#   "start_char": 263,
#   "end_char": 268
# }, {
#   "text": "Liberius",
#   "type": "PERSON",
#   "start_char": 292,
#   "end_char": 300
# }, {
#   "text": "Constantius",
#   "type": "PERSON",
#   "start_char": 419,
#   "end_char": 430
# }]
# [{
#   "text": "Felix",
#   "type": "PERSON",
#   "start_char": 161,
#   "end_char": 166
# }, {
#   "text": "Rome,",
#   "type": "PERSON",
#   "start_char": 285,
#   "end_char": 290
# }, {
#   "text": "Christian",
#   "type": "NORP",
#   "start_char": 312,
#   "end_char": 321
# }, {
#   "text": "Marius",
#   "type": "PERSON",
#   "start_char": 375,
#   "end_char": 381
# }, {
#   "text": "Constantinople",
#   "type": "GPE",
#   "start_char": 419,
#   "end_char": 433
# }]
# [{
#   "text": "Christians",
#   "type": "NORP",
#   "start_char": 38,
#   "end_char": 48
# }, {
#   "text": "Flavian",
#   "type": "NORP",
#   "start_char": 72,
#   "end_char": 79
# }, {
#   "text": "Rome, Alexandria,",
#   "type": "PERSON",
#   "start_char": 88,
#   "end_char": 105
# }, {
#   "text": "Infidels,",
#   "type": "NORP",
#   "start_char": 197,
#   "end_char": 206
# }]
# [{
#   "text": "Constantinople",
#   "type": "GPE",
#   "start_char": 0,
#   "end_char": 14
# }]
# [{
#   "text": "East",
#   "type": "LOC",
#   "start_char": 19,
#   "end_char": 23
# }, {
#   "text": "Christians",
#   "type": "NORP",
#   "start_char": 193,
#   "end_char": 203
# }]
# [{
#   "text": "Alexander the episcopal",
#   "type": "PERSON",
#   "start_char": 19,
#   "end_char": 42
# }, {
#   "text": "Paul",
#   "type": "PERSON",
#   "start_char": 66,
#   "end_char": 70
# }, {
#   "text": "Macedonius",
#   "type": "PERSON",
#   "start_char": 75,
#   "end_char": 85
# }]
# [{
#   "text": "Macedonius",
#   "type": "PERSON",
#   "start_char": 120,
#   "end_char": 130
# }]
# [{
#   "text": "Nicene",
#   "type": "PERSON",
#   "start_char": 27,
#   "end_char": 33
# }, {
#   "text": "Paul",
#   "type": "PERSON",
#   "start_char": 57,
#   "end_char": 61
# }, {
#   "text": "Arians",
#   "type": "NORP",
#   "start_char": 149,
#   "end_char": 155
# }]
# [{
#   "text": "the space of fourteen years",
#   "type": "DATE",
#   "start_char": 3,
#   "end_char": 30
# }, {
#   "text": "five",
#   "type": "CARDINAL",
#   "start_char": 38,
#   "end_char": 42
# }, {
#   "text": "Macedonius",
#   "type": "GPE",
#   "start_char": 199,
#   "end_char": 209
# }]
# [{
#   "text": "Paul",
#   "type": "PERSON",
#   "start_char": 16,
#   "end_char": 20
# }, {
#   "text": "Mesopotamia",
#   "type": "LOC",
#   "start_char": 69,
#   "end_char": 80
# }, {
#   "text": "Mount",
#   "type": "LOC",
#   "start_char": 112,
#   "end_char": 117
# }, {
#   "text": "six",
#   "type": "CARDINAL",
#   "start_char": 175,
#   "end_char": 178
# }, {
#   "text": "one",
#   "type": "CARDINAL",
#   "start_char": 247,
#   "end_char": 250
# }, {
#   "text": "first",
#   "type": "ORDINAL",
#   "start_char": 315,
#   "end_char": 320
# }]
# [{
#   "text": "Paul",
#   "type": "PERSON",
#   "start_char": 61,
#   "end_char": 65
# }, {
#   "text": "Hermogenes, the master-general of the cavalry,",
#   "type": "PERSON",
#   "start_char": 88,
#   "end_char": 134
# }]
# [{
#   "text": "Hermogenes",
#   "type": "PERSON",
#   "start_char": 65,
#   "end_char": 75
# }, {
#   "text": "first",
#   "type": "ORDINAL",
#   "start_char": 94,
#   "end_char": 99
# }]
# [{
#   "text": "Hermogenes",
#   "type": "PERSON",
#   "start_char": 18,
#   "end_char": 28
# }, {
#   "text": "Philip,",
#   "type": "PERSON",
#   "start_char": 40,
#   "end_char": 47
# }, {
#   "text": "Praetorian",
#   "type": "PERSON",
#   "start_char": 52,
#   "end_char": 62
# }]
# [{
#   "text": "Paul",
#   "type": "PERSON",
#   "start_char": 70,
#   "end_char": 74
# }, {
#   "text": "Zeuxippus,",
#   "type": "GPE",
#   "start_char": 91,
#   "end_char": 101
# }]
# [{
#   "text": "Thessalonica",
#   "type": "GPE",
#   "start_char": 195,
#   "end_char": 207
# }]
# [{
#   "text": "Macedonius",
#   "type": "PERSON",
#   "start_char": 102,
#   "end_char": 112
# }]
# [{
#   "text": "Arians",
#   "type": "NORP",
#   "start_char": 64,
#   "end_char": 70
# }, {
#   "text": "three thousand one",
#   "type": "CARDINAL",
#   "start_char": 139,
#   "end_char": 157
# }, {
#   "text": "hundred and fifty",
#   "type": "CARDINAL",
#   "start_char": 158,
#   "end_char": 175
# }]
# [{
#   "text": "Macedonius,",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 11
# }]
# [{
#   "text": "Constantine",
#   "type": "PERSON",
#   "start_char": 45,
#   "end_char": 56
# }, {
#   "text": "St",
#   "type": "GPE",
#   "start_char": 170,
#   "end_char": 172
# }]
# [{
#   "text": "Acacius",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 7
# }]
# [{
#   "text": "Homoousian",
#   "type": "NORP",
#   "start_char": 116,
#   "end_char": 126
# }]
# [{
#   "text": "one",
#   "type": "CARDINAL",
#   "start_char": 101,
#   "end_char": 104
# }]
# [{
#   "text": "Christians",
#   "type": "NORP",
#   "start_char": 361,
#   "end_char": 371
# }, {
#   "text": "Cruelty of the Arians",
#   "type": "PERSON",
#   "start_char": 396,
#   "end_char": 417
# }, {
#   "text": "Constantius,",
#   "type": "GPE",
#   "start_char": 457,
#   "end_char": 469
# }, {
#   "text": "Greeks",
#   "type": "NORP",
#   "start_char": 797,
#   "end_char": 803
# }, {
#   "text": "two",
#   "type": "CARDINAL",
#   "start_char": 836,
#   "end_char": 839
# }, {
#   "text": "Hermogenes,",
#   "type": "PERSON",
#   "start_char": 908,
#   "end_char": 919
# }, {
#   "text": "Constantinople",
#   "type": "GPE",
#   "start_char": 949,
#   "end_char": 963
# }]
# [{
#   "text": "Constantius",
#   "type": "GPE",
#   "start_char": 15,
#   "end_char": 26
# }, {
#   "text": "Theodosian",
#   "type": "NORP",
#   "start_char": 101,
#   "end_char": 111
# }, {
#   "text": "Arian",
#   "type": "NORP",
#   "start_char": 160,
#   "end_char": 165
# }, {
#   "text": "Christians;",
#   "type": "NORP",
#   "start_char": 279,
#   "end_char": 290
# }]
# [{
#   "text": "Thrace",
#   "type": "LOC",
#   "start_char": 53,
#   "end_char": 59
# }, {
#   "text": "Asia Minor",
#   "type": "LOC",
#   "start_char": 64,
#   "end_char": 74
# }, {
#   "text": "Macedonius;",
#   "type": "GPE",
#   "start_char": 104,
#   "end_char": 115
# }, {
#   "text": "Semi-Arian",
#   "type": "NORP",
#   "start_char": 218,
#   "end_char": 228
# }, {
#   "text": "Homoiousion",
#   "type": "PERSON",
#   "start_char": 258,
#   "end_char": 269
# }, {
#   "text": "Constantius",
#   "type": "PERSON",
#   "start_char": 321,
#   "end_char": 332
# }]
# [{
#   "text": "Macedonius",
#   "type": "GPE",
#   "start_char": 128,
#   "end_char": 138
# }]
# [{
#   "text": "Novatians",
#   "type": "NORP",
#   "start_char": 399,
#   "end_char": 408
# }, {
#   "text": "Constantinople",
#   "type": "GPE",
#   "start_char": 412,
#   "end_char": 426
# }, {
#   "text": "Homoousian",
#   "type": "NORP",
#   "start_char": 485,
#   "end_char": 495
# }]
# [{
#   "text": "Macedonius",
#   "type": "PERSON",
#   "start_char": 0,
#   "end_char": 10
# }, {
#   "text": "Paphlagonia",
#   "type": "GPE",
#   "start_char": 49,
#   "end_char": 60
# }]
# [{
#   "text": "four thousand",
#   "type": "CARDINAL",
#   "start_char": 157,
#   "end_char": 170
# }, {
#   "text": "Mantinium",
#   "type": "GPE",
#   "start_char": 243,
#   "end_char": 252
# }]
# [{
#   "text": "Novatian",
#   "type": "NORP",
#   "start_char": 4,
#   "end_char": 12
# }, {
#   "text": "Paphlagonians",
#   "type": "NORP",
#   "start_char": 137,
#   "end_char": 150
# }, {
#   "text": "Roman",
#   "type": "NORP",
#   "start_char": 167,
#   "end_char": 172
# }, {
#   "text": "four",
#   "type": "CARDINAL",
#   "start_char": 314,
#   "end_char": 318
# }, {
#   "text": "thousand",
#   "type": "CARDINAL",
#   "start_char": 319,
#   "end_char": 327
# }]
# [{
#   "text": "Constantius",
#   "type": "ORG",
#   "start_char": 17,
#   "end_char": 28
# }, {
#   "text": "East,",
#   "type": "NORP",
#   "start_char": 163,
#   "end_char": 168
# }]
# []
# [{
#   "text": "345",
#   "type": "CARDINAL",
#   "start_char": 0,
#   "end_char": 3
# }, {
#   "text": "Arian",
#   "type": "NORP",
#   "start_char": 32,
#   "end_char": 37
# }, {
#   "text": "African",
#   "type": "NORP",
#   "start_char": 89,
#   "end_char": 96
# }, {
#   "text": "Circumcellions,",
#   "type": "PERSON",
#   "start_char": 192,
#   "end_char": 207
# }, {
#   "text": "Donatist",
#   "type": "NORP",
#   "start_char": 247,
#   "end_char": 255
# }]
# [{
#   "text": "Constantine",
#   "type": "PERSON",
#   "start_char": 42,
#   "end_char": 53
# }, {
#   "text": "Constans",
#   "type": "PERSON",
#   "start_char": 138,
#   "end_char": 146
# }, {
#   "text": "first",
#   "type": "ORDINAL",
#   "start_char": 236,
#   "end_char": 241
# }, {
#   "text": "two",
#   "type": "CARDINAL",
#   "start_char": 325,
#   "end_char": 328
# }, {
#   "text": "Imperial",
#   "type": "NORP",
#   "start_char": 329,
#   "end_char": 337
# }, {
#   "text": "Paul",
#   "type": "PERSON",
#   "start_char": 353,
#   "end_char": 357
# }, {
#   "text": "Macarius,",
#   "type": "PERSON",
#   "start_char": 362,
#   "end_char": 371
# }]
# [{
#   "text": "Numidia",
#   "type": "GPE",
#   "start_char": 49,
#   "end_char": 56
# }, {
#   "text": "Mauritania",
#   "type": "GPE",
#   "start_char": 61,
#   "end_char": 71
# }, {
#   "text": "Roman",
#   "type": "NORP",
#   "start_char": 155,
#   "end_char": 160
# }, {
#   "text": "Christian",
#   "type": "NORP",
#   "start_char": 205,
#   "end_char": 214
# }, {
#   "text": "Donatist",
#   "type": "NORP",
#   "start_char": 300,
#   "end_char": 308
# }]
# []
# []
# []
# [{
#   "text": "Donatist",
#   "type": "NORP",
#   "start_char": 39,
#   "end_char": 47
# }, {
#   "text": "the Gaetulian desert,",
#   "type": "LOC",
#   "start_char": 102,
#   "end_char": 123
# }]
# [{
#   "text": "Circumcellions",
#   "type": "PERSON",
#   "start_char": 19,
#   "end_char": 33
# }, {
#   "text": "Africa",
#   "type": "LOC",
#   "start_char": 364,
#   "end_char": 370
# }]
# [{
#   "text": "first",
#   "type": "ORDINAL",
#   "start_char": 3,
#   "end_char": 8
# }]
# [{
#   "text": "Circumcellions",
#   "type": "NORP",
#   "start_char": 93,
#   "end_char": 107
# }]
# []
# [{
#   "text": "Circumcellions",
#   "type": "PERSON",
#   "start_char": 18,
#   "end_char": 32
# }, {
#   "text": "Bagai",
#   "type": "GPE",
#   "start_char": 185,
#   "end_char": 190
# }, {
#   "text": "Imperial",
#   "type": "ORG",
#   "start_char": 279,
#   "end_char": 287
# }]
# [{
#   "text": "Donatists",
#   "type": "PERSON",
#   "start_char": 4,
#   "end_char": 13
# }]
# []
# [{
#   "text": "the beginning of the present century",
#   "type": "DATE",
#   "start_char": 3,
#   "end_char": 39
# }, {
#   "text": "Circumcellions",
#   "type": "PERSON",
#   "start_char": 59,
#   "end_char": 73
# }, {
#   "text": "Camisards;",
#   "type": "PERSON",
#   "start_char": 162,
#   "end_char": 172
# }, {
#   "text": "Languedoc",
#   "type": "GPE",
#   "start_char": 196,
#   "end_char": 205
# }, {
#   "text": "Numidia",
#   "type": "GPE",
#   "start_char": 225,
#   "end_char": 232
# }, {
#   "text": "Africans",
#   "type": "NORP",
#   "start_char": 269,
#   "end_char": 277
# }, {
#   "text": "Donatists",
#   "type": "PERSON",
#   "start_char": 465,
#   "end_char": 474
# }]
# []
# []
# []
# []
# [{
#   "text": "one",
#   "type": "CARDINAL",
#   "start_char": 67,
#   "end_char": 70
# }, {
#   "text": "Satan,",
#   "type": "PERSON",
#   "start_char": 144,
#   "end_char": 150
# }, {
#   "text": "Jewish",
#   "type": "NORP",
#   "start_char": 318,
#   "end_char": 324
# }, {
#   "text": "Christian",
#   "type": "NORP",
#   "start_char": 358,
#   "end_char": 367
# }]
# []
# [{
#   "text": "Pagan",
#   "type": "NORP",
#   "start_char": 147,
#   "end_char": 152
# }]
# [{
#   "text": "Ammianus",
#   "type": "PERSON",
#   "start_char": 18,
#   "end_char": 26
# }, {
#   "text": "Christians",
#   "type": "NORP",
#   "start_char": 68,
#   "end_char": 78
# }, {
#   "text": "Gregory Nazianzen",
#   "type": "PERSON",
#   "start_char": 157,
#   "end_char": 174
# }]
# []
# []
# []
# []
# []
# [{
#   "text": "Athanasians",
#   "type": "NORP",
#   "start_char": 157,
#   "end_char": 168
# }, {
#   "text": "Arians",
#   "type": "NORP",
#   "start_char": 177,
#   "end_char": 183
# }, {
#   "text": "Montesquieu,",
#   "type": "PERSON",
#   "start_char": 546,
#   "end_char": 558
# }, {
#   "text": "Constantine,",
#   "type": "GPE",
#   "start_char": 644,
#   "end_char": 656
# }, {
#   "text": "Pagan",
#   "type": "NORP",
#   "start_char": 686,
#   "end_char": 691
# }]
# [{
#   "text": "Imperial",
#   "type": "NORP",
#   "start_char": 322,
#   "end_char": 330
# }, {
#   "text": "Constantine",
#   "type": "PERSON",
#   "start_char": 389,
#   "end_char": 400
# }]
# [{
#   "text": "Roman",
#   "type": "NORP",
#   "start_char": 72,
#   "end_char": 77
# }]
# [{
#   "text": "Paganism",
#   "type": "NORP",
#   "start_char": 32,
#   "end_char": 40
# }]
# [{
#   "text": "Pagans,",
#   "type": "NORP",
#   "start_char": 87,
#   "end_char": 94
# }]
# [{
#   "text": "Christian",
#   "type": "NORP",
#   "start_char": 102,
#   "end_char": 111
# }, {
#   "text": "Constantine",
#   "type": "PERSON",
#   "start_char": 199,
#   "end_char": 210
# }]
# []
# [{
#   "text": "Nile",
#   "type": "LOC",
#   "start_char": 139,
#   "end_char": 143
# }, {
#   "text": "Constantine",
#   "type": "PERSON",
#   "start_char": 164,
#   "end_char": 175
# }, {
#   "text": "Roman",
#   "type": "NORP",
#   "start_char": 203,
#   "end_char": 208
# }, {
#   "text": "Phoenicia,",
#   "type": "GPE",
#   "start_char": 278,
#   "end_char": 288
# }, {
#   "text": "Constantinople",
#   "type": "GPE",
#   "start_char": 422,
#   "end_char": 436
# }, {
#   "text": "Greece",
#   "type": "GPE",
#   "start_char": 541,
#   "end_char": 547
# }, {
#   "text": "Asia;",
#   "type": "GPE",
#   "start_char": 552,
#   "end_char": 557
# }]
# [{
#   "text": "Roman",
#   "type": "NORP",
#   "start_char": 60,
#   "end_char": 65
# }]
# [{
#   "text": "Constantine",
#   "type": "PERSON",
#   "start_char": 12,
#   "end_char": 23
# }]
# [{
#   "text": "Christians;",
#   "type": "NORP",
#   "start_char": 132,
#   "end_char": 143
# }, {
#   "text": "Paganism,",
#   "type": "NORP",
#   "start_char": 193,
#   "end_char": 202
# }, {
#   "text": "one",
#   "type": "CARDINAL",
#   "start_char": 255,
#   "end_char": 258
# }, {
#   "text": "Constans",
#   "type": "NORP",
#   "start_char": 300,
#   "end_char": 308
# }, {
#   "text": "Constantius",
#   "type": "PERSON",
#   "start_char": 313,
#   "end_char": 324
# }]
# [{
#   "text": "Constantius",
#   "type": "PERSON",
#   "start_char": 18,
#   "end_char": 29
# }]
# []
# [{
#   "text": "Pagan",
#   "type": "NORP",
#   "start_char": 130,
#   "end_char": 135
# }, {
#   "text": "Constantine",
#   "type": "PERSON",
#   "start_char": 182,
#   "end_char": 193
# }]
# [{
#   "text": "East",
#   "type": "LOC",
#   "start_char": 7,
#   "end_char": 11
# }, {
#   "text": "West,",
#   "type": "LOC",
#   "start_char": 30,
#   "end_char": 35
# }]
# [{
#   "text": "About four years",
#   "type": "DATE",
#   "start_char": 0,
#   "end_char": 16
# }, {
#   "text": "Constantius",
#   "type": "PERSON",
#   "start_char": 62,
#   "end_char": 73
# }, {
#   "text": "Rome;",
#   "type": "GPE",
#   "start_char": 97,
#   "end_char": 102
# }, {
#   "text": "Pagan",
#   "type": "NORP",
#   "start_char": 156,
#   "end_char": 161
# }]
# [{
#   "text": "Constantine",
#   "type": "PERSON",
#   "start_char": 103,
#   "end_char": 114
# }]
# [{
#   "text": "Numa,",
#   "type": "PERSON",
#   "start_char": 93,
#   "end_char": 98
# }, {
#   "text": "Augustus,",
#   "type": "PERSON",
#   "start_char": 114,
#   "end_char": 123
# }, {
#   "text": "seven",
#   "type": "CARDINAL",
#   "start_char": 162,
#   "end_char": 167
# }, {
#   "text": "Christian",
#   "type": "NORP",
#   "start_char": 168,
#   "end_char": 177
# }]
# [{
#   "text": "Christianity",
#   "type": "NORP",
#   "start_char": 23,
#   "end_char": 35
# }, {
#   "text": "(173)",
#   "type": "CARDINAL",
#   "start_char": 68,
#   "end_char": 73
# }]
# [{
#   "text": "Imperial",
#   "type": "NORP",
#   "start_char": 162,
#   "end_char": 170
# }]
# [{
#   "text": "Christianity;",
#   "type": "NORP",
#   "start_char": 92,
#   "end_char": 105
# }, {
#   "text": "two",
#   "type": "CARDINAL",
#   "start_char": 110,
#   "end_char": 113
# }, {
#   "text": "three",
#   "type": "CARDINAL",
#   "start_char": 117,
#   "end_char": 122
# }]
# [{
#   "text": "Roman",
#   "type": "NORP",
#   "start_char": 69,
#   "end_char": 74
# }]
# [{
#   "text": "Constantine",
#   "type": "PERSON",
#   "start_char": 85,
#   "end_char": 96
# }, {
#   "text": "Constantius;",
#   "type": "PERSON",
#   "start_char": 101,
#   "end_char": 113
# }]
# []
# [{
#   "text": "Gaul",
#   "type": "PERSON",
#   "start_char": 226,
#   "end_char": 230
# }]

# %%
NER_Dict= {}    #token.text will show the text of each word, #token.ner will show NER, will == 'O' if token is not a named entity
for doc in Out_Docs:
    for sent in doc.sentences:
        for token in sent.tokens:
            if token.ner == 'O':
                continue
            else:
                NER_Dict[token.text]= token.ner
            print(f'{token.text},{token.ner}')
            
#create a dictionary (NER_Dict) where the key is the token text and the value is the named entity tag
# Out:
# The,B-WORK_OF_ART
# Schism,I-WORK_OF_ART
# of,I-WORK_OF_ART
# the,I-WORK_OF_ART
# Donatists,E-WORK_OF_ART
# The,B-WORK_OF_ART
# Arian,I-WORK_OF_ART
# Controversy,I-WORK_OF_ART
# —,I-WORK_OF_ART
# Athanasius,I-WORK_OF_ART
# —,I-WORK_OF_ART
# Distracted,I-WORK_OF_ART
# state,I-WORK_OF_ART
# of,I-WORK_OF_ART
# the,I-WORK_OF_ART
# Church,I-WORK_OF_ART
# and,I-WORK_OF_ART
# the,I-WORK_OF_ART
#
# Circumcellions,S-PERSON
# Africa,S-LOC
# first,S-ORDINAL
# Circumcellions,S-NORP
# Circumcellions,S-PERSON
# Bagai,S-GPE
# Imperial,S-ORG
# Donatists,S-PERSON
# the,B-DATE
# beginning,I-DATE
# of,I-DATE
# the,I-DATE
# present,I-DATE
# century,E-DATE
# Circumcellions,S-PERSON
# Camisards;,S-PERSON
# Languedoc,S-GPE
# Numidia,S-GPE
# Africans,S-NORP
# Donatists,S-PERSON
# one,S-CARDINAL
# Satan,,S-PERSON
# Jewish,S-NORP
# Christian,S-NORP
# Pagan,S-NORP
# Ammianus,S-PERSON
# Christians,S-NORP
# Gregory,B-PERSON
# Nazianzen,E-PERSON
# Athanasians,S-NORP
# Arians,S-NORP
# Montesquieu,,S-PERSON
# Constantine,,S-GPE
# Pagan,S-NORP
# Imperial,S-NORP
# Constantine,S-PERSON
# Roman,S-NORP
# Paganism,S-NORP
# Pagans,,S-NORP
# Christian,S-NORP
# Constantine,S-PERSON
# Nile,S-LOC
# Constantine,S-PERSON
# Roman,S-NORP
# Phoenicia,,S-GPE
# Constantinople,S-GPE
# Greece,S-GPE
# Asia;,S-GPE
# Roman,S-NORP
# Constantine,S-PERSON
# Christians;,S-NORP
# Paganism,,S-NORP
# one,S-CARDINAL
# Constans,S-NORP
# Constantius,S-PERSON
# Constantius,S-PERSON
# Pagan,S-NORP
# Constantine,S-PERSON
# East,S-LOC
# West,,S-LOC
# About,B-DATE
# four,I-DATE
# years,E-DATE
# Constantius,S-PERSON
# Rome;,S-GPE
# Pagan,S-NORP
# Constantine,S-PERSON
# Numa,,S-PERSON
# Augustus,,S-PERSON
# seven,S-CARDINAL
# Christian,S-NORP
# Christianity,S-NORP
# (173),S-CARDINAL
# Imperial,S-NORP
# Christianity;,S-NORP
# two,S-CARDINAL
# three,S-CARDINAL
# Roman,S-NORP
# Constantine,S-PERSON
# Constantius;,S-PERSON
# Gaul,S-PERSON

# %%
# sanity check
NER_Dict
# Out:
# {'The': 'B-PERSON',
#  'Schism': 'B-PERSON',
#  'of': 'I-DATE',
#  'the': 'I-DATE',
#  'Donatists': 'S-PERSON',
#  'Arian': 'S-NORP',
#  'Controversy': 'I-WORK_OF_ART',
#  '—': 'I-WORK_OF_ART',
#  'Athanasius': 'S-PERSON',
#  'Distracted': 'I-WORK_OF_ART',
#  'state': 'I-WORK_OF_ART',
#  'Church': 'I-WORK_OF_ART',
#  'and': 'I-CARDINAL',
#  'Empire': 'I-WORK_OF_ART',
#  'under': 'I-WORK_OF_ART',
#  'Constantine': 'S-PERSON',
#  'Toleration': 'B-WORK_OF_ART',
#  'Paganism': 'S-NORP',
#  'Milan,': 'B-PERSON',
#  'Roman': 'S-NORP',
#  'Catholic': 'S-NORP',
#  'Christianity': 'S-NORP',
#  'East': 'S-LOC',
#  'Paul': 'S-PERSON',
#  'Samosata;': 'I-PERSON',
#  'Montanists': 'I-PERSON',
#  'Phrygia,': 'E-PERSON',
#  'Novatians,': 'S-NORP',
#  'Marcionites': 'S-NORP',
#  'Valentinians,': 'S-NORP',
#  'Gnostics': 'S-NORP',
#  'Asia': 'B-LOC',
#  'Egypt': 'S-GPE',
#  'Manichaeans,': 'S-NORP',
#  'Persia': 'S-GPE',
#  'Oriental': 'S-NORP',
#  'Christian': 'S-NORP',
#  'Diocletian;': 'S-PERSON',
#  'Two': 'B-DATE',
#  'Manichaeans': 'S-NORP',
#  'Constantinople;': 'S-GPE',
#  'Acesius,': 'S-PERSON',
#  'Nice;': 'S-PERSON',
#  'African': 'S-NORP',
#  '312': 'S-CARDINAL',
#  'Constantine,': 'S-GPE',
#  'Maxentius': 'S-PERSON',
#  'Africa': 'S-LOC',
#  'Columns': 'I-ORG',
#  'Hercules,': 'E-ORG',
#  'Carthage,': 'S-GPE',
#  'second': 'S-ORDINAL',
#  'West': 'S-LOC',
#  'Caecilian': 'E-GPE',
#  'Majourinus': 'S-ORG',
#  'two': 'S-CARDINAL',
#  'Cacilian': 'S-PERSON',
#  'Numidia': 'S-GPE',
#  'Caecilian,': 'S-PERSON',
#  'Majorinus,': 'S-PERSON',
#  'Numidian': 'S-NORP',
#  'Holy': 'I-WORK_OF_ART',
#  'Scriptures': 'E-PERSON',
#  'Diocletian': 'S-PERSON',
#  'Christians': 'S-NORP',
#  'five': 'S-CARDINAL',
#  'first': 'S-ORDINAL',
#  'three': 'S-CARDINAL',
#  'years': 'E-DATE',
#  'Africa,': 'E-ORG',
#  'Rome': 'S-GPE',
#  'Arles,': 'S-PERSON',
#  'Caecilian;': 'S-PERSON',
#  'Donatist': 'S-NORP',
#  'Osius': 'S-PERSON',
#  'Donatists,': 'I-PERSON',
#  'A.D': 'E-GPE',
#  '315': 'S-CARDINAL',
#  'Europe': 'S-LOC',
#  'East,': 'S-NORP',
#  'Eucharist': 'E-PERSON',
#  'Numidia,': 'S-GPE',
#  'four': 'I-DATE',
#  'hundred': 'B-CARDINAL',
#  'fourth': 'S-ORDINAL',
#  'Rogatians': 'S-NORP',
#  'Caesarean': 'I-LOC',
#  'Mauritania.(10)': 'E-LOC',
#  'Trinitarian': 'S-NORP',
#  'Clovis': 'S-PERSON',
#  'Theodoric,': 'S-PERSON',
#  'Romans': 'S-NORP',
#  'Arianism': 'S-NORP',
#  'Plato': 'S-PERSON',
#  'Christ': 'B-PERSON',
#  '360': 'E-PERSON',
#  'Plato,': 'S-GPE',
#  'Athenian': 'S-NORP',
#  'Platonic': 'S-NORP',
#  'Logos': 'S-ORG',
#  'Son': 'I-PERSON',
#  'an': 'B-DATE',
#  'Eternal': 'E-PERSON',
#  'Academy;': 'S-NORP',
#  'thirty': 'B-DATE',
#  'years.(12)': 'E-DATE',
#  'Alexandria': 'S-GPE',
#  '300': 'E-PERSON',
#  'Macedonians': 'S-NORP',
#  'Greece;': 'S-LANGUAGE',
#  'Alexandria.': 'S-GPE',
#  'Jews': 'S-NORP',
#  'Hebrews': 'S-NORP',
#  'Egyptian': 'S-NORP',
#  'One': 'S-CARDINAL',
#  'before': 'E-DATE',
#  'Christ,': 'E-PERSON',
#  'Alexandrian': 'S-NORP',
#  'Solomon': 'S-PERSON',
#  'Mosaic': 'S-NORP',
#  'Grecian': 'S-NORP',
#  'Philo,': 'S-PERSON',
#  'Hebrews;': 'S-PERSON',
#  'to': 'I-WORK_OF_ART',
#  'Jehovah': 'I-WORK_OF_ART',
#  'Moses': 'E-WORK_OF_ART',
#  'God': 'E-PERSON',
#  'Apostle': 'I-PERSON',
#  'St': 'S-GPE',
#  'John,': 'I-PERSON',
#  '97': 'S-CARDINAL',
#  'Alexandria,': 'E-PERSON',
#  'Deity,': 'E-PERSON',
#  'Academy,': 'B-PERSON',
#  'Porch,': 'E-PERSON',
#  'Nerva,': 'S-PERSON',
#  'Jesus': 'S-PERSON',
#  'Nazareth;': 'E-PERSON',
#  'Ebionites': 'S-PERSON',
#  'Docetes': 'S-ORG',
#  'Nazarenes,(23)': 'S-PERSON',
#  'Hewbrew': 'S-NORP',
#  'God,': 'E-PERSON',
#  'John': 'S-PERSON',
#  'About': 'B-DATE',
#  'fifty': 'E-CARDINAL',
#  'Ebionites,': 'S-NORP',
#  'Justin': 'B-PERSON',
#  'Martyr,': 'E-PERSON',
#  'Gnostics,': 'S-NORP',
#  'Aeon,': 'S-PERSON',
#  'Emanation': 'B-PERSON',
#  'Mount': 'S-LOC',
#  'Calvary,': 'E-LOC',
#  'Virgin,(27)': 'S-PERSON',
#  'Jordan': 'S-GPE',
#  'Pilate': 'S-PERSON',
#  'days,': 'E-DATE',
#  'Mysterious': 'B-PERSON',
#  'nature': 'I-PERSON',
#  'Trinity': 'E-PERSON',
#  'third': 'I-TIME',
#  'centuries': 'E-DATE',
#  'Trinity,(31)': 'S-PERSON',
#  'divinity': 'I-PERSON',
#  'Logos,': 'E-PERSON',
#  'Zeal': 'B-PERSON',
#  'Christians.': 'E-PERSON',
#  'Athens': 'S-GPE',
#  'Tertullian': 'S-PERSON',
#  'Greek': 'S-NORP',
#  'eternal': 'E-PERSON',
#  'Bithynia': 'S-GPE',
#  'Pliny': 'S-PERSON',
#  'Father': 'I-PERSON',
#  'Platonists:': 'S-NORP',
#  'Praxeas': 'S-GPE',
#  'Sabellius': 'S-PERSON',
#  'with': 'I-PERSON',
#  'Son,': 'E-PERSON',
#  'Sabellians': 'S-PERSON',
#  'Rome,': 'B-PERSON',
#  'Egypt,': 'E-PERSON',
#  'Alexandria;': 'S-GPE',
#  'Arius': 'S-PERSON',
#  'Alexander': 'B-PERSON',
#  'seven': 'S-CARDINAL',
#  'twelve': 'S-CARDINAL',
#  'Eusebius': 'E-PERSON',
#  'Nicomedia,': 'S-GPE',
#  'Palestine': 'S-GPE',
#  'six': 'S-CARDINAL',
#  'general': 'I-ORG',
#  'council': 'I-ORG',
#  'Nice.': 'E-ORG',
#  'Three': 'S-CARDINAL',
#  'Almighty': 'I-PERSON',
#  'Caesar': 'S-PERSON',
#  'will': 'I-PERSON',
#  'his': 'I-PERSON',
#  'Sabellian': 'S-NORP',
#  'Ebionite': 'S-NORP',
#  'Council': 'B-ORG',
#  'Nice,': 'S-PERSON',
#  '325': 'S-CARDINAL',
#  'Nice(55)': 'E-ORG',
#  'Arians': 'S-NORP',
#  'Ambrose,': 'S-PERSON',
#  'consubstantiality': 'I-PERSON',
#  'Greek,': 'I-PERSON',
#  'Latin,': 'I-PERSON',
#  'Oriental,': 'E-PERSON',
#  'Protestant': 'S-NORP',
#  'Tritheists': 'S-NORP',
#  'about': 'B-DATE',
#  'Antioch(57)': 'S-PERSON',
#  'Athanasius,': 'S-GPE',
#  'Gregory': 'B-PERSON',
#  'Nazianzen,': 'E-PERSON',
#  'Nicene': 'S-PERSON',
#  'Father,': 'E-WORK_OF_ART',
#  'Arians,(61)': 'S-PERSON',
#  'twenty': 'I-DATE',
#  'Sabellianism': 'I-PERSON',
#  'Marcellus': 'I-PERSON',
#  'Ancyra;': 'E-PERSON',
#  'Creeds': 'E-PERSON',
#  'eighteen': 'S-CARDINAL',
#  'Hilary,': 'S-PERSON',
#  'ten': 'S-CARDINAL',
#  'Poitiers': 'S-GPE',
#  'Sects': 'E-PERSON',
#  'Homoousion': 'S-PERSON',
#  'Arius,': 'S-PERSON',
#  'Atheist': 'S-NORP',
#  'Aristotle,': 'S-GPE',
#  'Aetius': 'S-PERSON',
#  'Son;': 'E-PERSON',
#  'Eusebian': 'S-NORP',
#  'Aetius;': 'S-NORP',
#  'Scriptures,': 'I-WORK_OF_ART',
#  'that': 'B-TIME',
#  'Asia;': 'S-GPE',
#  'Seleucia,': 'B-GPE',
#  'one': 'S-CARDINAL',
#  'forty-three': 'E-CARDINAL',
#  'Homoousians': 'S-NORP',
#  'Homoiousians': 'S-NORP',
#  'Catholics': 'S-NORP',
#  'bishop': 'I-PERSON',
#  'Poitiers,': 'E-PERSON',
#  'Phrygian': 'S-NORP',
#  'Semi-Arians,': 'S-NORP',
#  'Western': 'S-NORP',
#  'Latin': 'S-NORP',
#  'Asia,': 'S-NORP',
#  'Greeks,': 'S-NORP',
#  'Gallican': 'S-NORP',
#  'Hilary': 'B-PERSON',
#  'Latins': 'S-NORP',
#  'Gospel': 'S-WORK_OF_ART',
#  'Rimi,': 'I-ORG',
#  'Rimini,': 'S-GPE',
#  'Italy,': 'I-ORG',
#  'Spain,': 'B-PERSON',
#  'Gaul,': 'S-GPE',
#  'Britain,': 'E-PERSON',
#  'Illyricum': 'S-GPE',
#  'Valens': 'S-PERSON',
#  'Ursacius,': 'S-PERSON',
#  'Illyricum,': 'E-ORG',
#  'Rimini': 'S-GPE',
#  'Jerom,': 'S-PERSON',
#  'Homoousian': 'S-NORP',
#  'King': 'I-PERSON',
#  'Heaven': 'E-PERSON',
#  '324': 'S-CARDINAL',
#  'Constantine,(78)': 'S-PERSON',
#  'Osius,': 'S-PERSON',
#  'Constantine;': 'S-PERSON',
#  'Casarea': 'S-GPE',
#  'Nicomedian': 'I-WORK_OF_ART',
#  'months': 'E-DATE',
#  'Illyricum;': 'S-GPE',
#  'Porphyrians;': 'S-PERSON',
#  'Christ.(82)': 'S-PERSON',
#  'Eusebius,': 'S-PERSON',
#  'Jerusalem;': 'S-GPE',
#  'Constantinople': 'S-GPE',
#  'same': 'I-DATE',
#  'day': 'E-DATE',
#  'Eustathius': 'S-PERSON',
#  'Antioch,': 'B-WORK_OF_ART',
#  'Nicomedia': 'S-GPE',
#  'Nice': 'B-PERSON',
#  'Constantius': 'S-PERSON',
#  'Constantius,': 'S-GPE',
#  'Magnentius': 'S-PERSON',
#  'Mursa,': 'S-PERSON',
#  'war,': 'B-PERSON',
#  'son': 'I-PERSON',
#  'Gallic': 'S-NORP',
#  'Arians,': 'S-NORP',
#  'Cyril,': 'S-PERSON',
#  'Jerusalem,': 'S-GPE',
#  'Pentecost,': 'S-EVENT',
#  'hour': 'E-TIME',
#  'Olives,': 'E-LOC',
#  'Councils': 'E-ORG',
#  'Ammianus,': 'S-PERSON',
#  'Sirmium,': 'E-FAC',
#  'Constantinople,': 'S-GPE',
#  'eunuchs,': 'I-PERSON',
#  'women,': 'E-PERSON',
#  'Homoousion;': 'S-NORP',
#  'Gallus;': 'S-PERSON',
#  'Imperial': 'S-NORP',
#  'Antioch': 'S-GPE',
#  'Semi-Arian': 'S-NORP',
#  'Isauria;': 'S-GPE',
#  'Hadriatic,': 'S-LOC',
#  'days': 'E-DATE',
#  'seventh': 'S-ORDINAL',
#  'Praetorian': 'S-PERSON',
#  'fifteen': 'S-CARDINAL',
#  'God.(95)': 'E-PERSON',
#  'Trinity,': 'S-NORP',
#  'Alexander,': 'S-PERSON',
#  'deacon': 'I-PERSON',
#  'Five': 'S-CARDINAL',
#  'Basil;': 'S-PERSON',
#  'Alexandrians': 'S-NORP',
#  'Nile': 'S-LOC',
#  'Ethiopia;': 'S-GPE',
#  '330': 'S-CARDINAL',
#  'Meletius.(102)': 'B-PERSON',
#  'Arsenius,': 'S-PERSON',
#  'Dalmatius,': 'S-PERSON',
#  'Caesarea': 'S-GPE',
#  'Tyre': 'S-GPE',
#  'Jerusalem': 'S-GPE',
#  'Meletians;': 'S-PERSON',
#  'Arsenius': 'S-NORP',
#  'Caesarea,': 'S-GPE',
#  '336': 'S-CARDINAL',
#  'Tyre,': 'S-GPE',
#  "Constantine's": 'S-PERSON',
#  'Treves,': 'B-ORG',
#  'twenty-eight': 'I-DATE',
#  '338': 'S-CARDINAL',
#  '341': 'S-CARDINAL',
#  'Eusebians': 'S-PERSON',
#  'Ninety': 'S-CARDINAL',
#  'Semi-Arianism,': 'S-NORP',
#  'twenty-five': 'S-CARDINAL',
#  'Greeks': 'S-NORP',
#  'Athanasius;': 'S-PERSON',
#  'Gregory,': 'S-PERSON',
#  'Asiatic': 'S-NORP',
#  'Julius:': 'S-PERSON',
#  'Italy': 'S-GPE',
#  'Milan': 'S-GPE',
#  'Constans,': 'S-PERSON',
#  'Constans': 'S-NORP',
#  'Ninety-four': 'S-CARDINAL',
#  'West,': 'S-LOC',
#  'Sardica,': 'S-GPE',
#  'dominions': 'I-PERSON',
#  'protector': 'I-PERSON',
#  'Thrace;': 'S-GPE',
#  'East.(115)': 'B-ORG',
#  'Sardica': 'E-ORG',
#  '349': 'S-CARDINAL',
#  'Capua,': 'S-GPE',
#  'Lodi,': 'B-ORG',
#  'Verona,': 'I-ORG',
#  'Padua,': 'I-ORG',
#  'Aquileia,': 'E-ORG',
#  'Treves': 'S-GPE',
#  'Syria;': 'S-NORP',
#  'Constantius;': 'S-PERSON',
#  'Alexandrians;': 'S-PERSON',
#  'Ethiopia': 'S-GPE',
#  '351': 'S-CARDINAL',
#  'years,': 'E-DATE',
#  'Arles': 'S-GPE',
#  'Eastern': 'S-NORP',
#  'Archbishop': 'I-PERSON',
#  'Sardica(126)': 'S-GPE',
#  '355': 'S-CARDINAL',
#  'Athanasius)': 'S-PERSON',
#  'Eastern,': 'S-NORP',
#  'Liberius': 'S-PERSON',
#  'Cordova,': 'S-PERSON',
#  'Paulinus': 'E-PERSON',
#  'Dionysius': 'E-ORG',
#  'Vercellae,': 'B-PERSON',
#  'Lucifer': 'E-PERSON',
#  'Cagliari,': 'S-GPE',
#  'Liberius,': 'S-PERSON',
#  'Cordova': 'S-GPE',
#  'Spaniard': 'S-NORP',
#  'Maximian': 'S-PERSON',
#  'Roman,': 'E-PERSON',
#  'Beraea': 'S-PERSON',
#  'Thrace,': 'S-PERSON',
#  'years;': 'E-DATE',
#  'Cappadocia,': 'S-GPE',
#  'likeness,': 'I-PERSON',
#  'Third': 'S-ORDINAL',
#  '356': 'S-CARDINAL',
#  'Six-and-twenty': 'B-DATE',
#  'court': 'E-ORG',
#  'Upper': 'I-PERSON',
#  'Libya,': 'S-NORP',
#  'twenty-three': 'B-DATE',
#  'Syrianus,': 'B-PERSON',
#  'duke': 'I-PERSON',
#  'thousand': 'S-CARDINAL',
#  'Syrianus': 'S-GPE',
#  'Pagans': 'S-NORP',
#  'George': 'S-PERSON',
#  'Cappadocia': 'S-GPE',
#  'Sebastian,': 'S-PERSON',
#  'more': 'B-CARDINAL',
#  'than': 'I-CARDINAL',
#  'ninety': 'E-CARDINAL',
#  'George,': 'S-PERSON',
#  'memorable': 'I-TIME',
#  'night': 'E-TIME',
#  'Theonas': 'S-PERSON',
#  'David': 'S-PERSON',
#  'Israel': 'S-GPE',
#  'moment': 'E-TIME',
#  '356-362': 'S-CARDINAL',
#  'Ethiopia,': 'S-NORP',
#  'Antony': 'S-PERSON',
#  'Pachomius': 'S-PERSON',
#  'Nile;': 'S-LOC',
#  'Tabenne': 'S-PERSON',
#  'several': 'B-CARDINAL',
#  'only': 'B-DATE',
#  'age,': 'E-DATE',
#  'midnight,': 'E-TIME',
#  '(143)': 'E-GPE',
#  'Mediterranean': 'S-LOC',
#  'Arians;': 'S-PERSON',
#  'Anti-christ': 'I-PERSON',
#  'church': 'E-PERSON',
#  'Gallus,': 'S-PERSON',
#  'Sylvanus,': 'S-PERSON',
#  'Magnentius,': 'S-PERSON',
#  'Bishops': 'E-PERSON',
#  'Christians,': 'S-NORP',
#  'Flavianus': 'B-ORG',
#  'Diodorus,': 'E-ORG',
#  'Glory': 'I-WORK_OF_ART',
#  'Ghost': 'E-WORK_OF_ART',
#  'three,': 'B-CARDINAL',
#  'or': 'I-CARDINAL',
#  'even': 'I-CARDINAL',
#  'Felix,': 'S-ORG',
#  'Circus': 'S-FAC',
#  'Felix': 'S-PERSON',
#  'Marius': 'S-PERSON',
#  'Flavian': 'S-NORP',
#  'Infidels,': 'S-NORP',
#  'episcopal': 'E-PERSON',
#  'Macedonius': 'S-PERSON',
#  'space': 'I-DATE',
#  'fourteen': 'I-DATE',
#  'Mesopotamia': 'S-LOC',
#  'Hermogenes,': 'S-PERSON',
#  'master-general': 'I-PERSON',
#  'cavalry,': 'E-PERSON',
#  'Hermogenes': 'S-PERSON',
#  'Philip,': 'S-PERSON',
#  'Zeuxippus,': 'S-GPE',
#  'Thessalonica': 'S-GPE',
#  'Macedonius,': 'S-PERSON',
#  'Acacius': 'S-PERSON',
#  'Cruelty': 'B-PERSON',
#  'Theodosian': 'S-NORP',
#  'Christians;': 'S-NORP',
#  'Thrace': 'S-LOC',
#  'Minor': 'E-LOC',
#  'Macedonius;': 'S-GPE',
#  'Homoiousion': 'S-PERSON',
#  'Novatians': 'S-NORP',
#  'Paphlagonia': 'S-GPE',
#  'Mantinium': 'S-GPE',
#  'Novatian': 'S-NORP',
#  'Paphlagonians': 'S-NORP',
#  '345': 'S-CARDINAL',
#  'Circumcellions,': 'S-PERSON',
#  'Macarius,': 'S-PERSON',
#  'Mauritania': 'S-GPE',
#  'Gaetulian': 'I-LOC',
#  'desert,': 'E-LOC',
#  'Circumcellions': 'S-PERSON',
#  'Bagai': 'S-GPE',
#  'beginning': 'I-DATE',
#  'present': 'I-DATE',
#  'century': 'E-DATE',
#  'Camisards;': 'S-PERSON',
#  'Languedoc': 'S-GPE',
#  'Africans': 'S-NORP',
#  'Satan,': 'S-PERSON',
#  'Jewish': 'S-NORP',
#  'Pagan': 'S-NORP',
#  'Ammianus': 'S-PERSON',
#  'Nazianzen': 'E-PERSON',
#  'Athanasians': 'S-NORP',
#  'Montesquieu,': 'S-PERSON',
#  'Pagans,': 'S-NORP',
#  'Phoenicia,': 'S-GPE',
#  'Greece': 'S-GPE',
#  'Paganism,': 'S-NORP',
#  'Rome;': 'S-GPE',
#  'Numa,': 'S-PERSON',
#  'Augustus,': 'S-PERSON',
#  '(173)': 'S-CARDINAL',
#  'Christianity;': 'S-NORP',
#  'Gaul': 'S-PERSON'}

# %%
ner_frame= pd.DataFrame.from_dict(NER_Dict, orient= 'index')  #creates a pandas dataframe from dictionary 
ner_frame
# Out:
#                         0
# The              B-PERSON
# Schism           B-PERSON
# of                 I-DATE
# the                I-DATE
# Donatists        S-PERSON
# ...                   ...
# Numa,            S-PERSON
# Augustus,        S-PERSON
# (173)          S-CARDINAL
# Christianity;      S-NORP
# Gaul             S-PERSON
#
# [524 rows x 1 columns]

# %%
ner_frame_indexed= ner_frame.reset_index()

# %%
ner_frame_indexed.rename(columns={'index':'token', 0: 'NER_tag'})
# Out:
#      level_0          token     NER_tag
# 0          0            The    B-PERSON
# 1          1         Schism    B-PERSON
# 2          2             of      I-DATE
# 3          3            the      I-DATE
# 4          4      Donatists    S-PERSON
# ..       ...            ...         ...
# 519      519          Numa,    S-PERSON
# 520      520      Augustus,    S-PERSON
# 521      521          (173)  S-CARDINAL
# 522      522  Christianity;      S-NORP
# 523      523           Gaul    S-PERSON
#
# [524 rows x 3 columns]
